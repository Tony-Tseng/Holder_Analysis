# %%
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np
import requests
import json

# %% [markdown]
# ## Enter your API keys from Moralis

# %%
headers = {
    'accept': 'application/json',
    'X-API-Key': 'pkhgpCPTU5AFiwXHrTwNCVXBIPfS3HZBLpOp1YOc8SOKxA8dUSVCEt9sg8hFjokU',
}

# %% [markdown]
# ## Enter the Contract address that you want to explore

# %%
contract_addr = "0xb47e3cd837ddf8e4c57f05d70ab865de6e193bbb"

# %% [markdown]
# ## To get All Owners of the NFT

# %%
params = {
    'chain': 'eth',
    'format': 'decimal',
}
url = f'https://deep-index.moralis.io/api/v2/nft/{contract_addr}/owners'

holder_list = requests.get(url, headers=headers, params=params)

# %%
with open('Holder_address.json', 'w') as outfile:
    outfile.write(holder_list.text)

# %% [markdown]
# ## Get the Balance in the wallet of each owners

# %%
params = {
    'chain': 'eth',
}

# %%
owner_list = []
owner_result = []
for result in json.loads(holder_list.text)["result"]:
    if(len(owner_list)<20):
        owner_list.append(result["owner_of"])
    else:
        owner_addr = ",".join(owner_list)
        url = f"https://api.etherscan.io/api?module=account&action=balancemulti&address={owner_addr}&tag=latest&apikey=57GBAHGQSE3CMYNZQY81V1N32YJZNCCUNZ"
        response = requests.get(url, verify=True)
        result = json.loads(response.text)["result"]
        owner_result.extend(result)
        owner_list = []

# %%
pd_owner_result = pd.DataFrame(owner_result)
owner_value_count = pd_owner_result.value_counts(subset="account").to_frame().reset_index()
owner_value_count.columns = ["account", "counts"]
pd_unique_owner = pd_owner_result.drop_duplicates(ignore_index=True)

pd_owner = pd_unique_owner.merge(owner_value_count, on="account")
pd_owner["balance"] = pd_owner["balance"].astype(float)/1e18

# pd_owner.sort_values(by="counts")
# pd_owner.sort_values(by="balance")

# %%
owner_json = pd_owner.to_json(orient="records")
with open('Holders_balance.json', 'w') as outfile:
    outfile.write(owner_json)

# %% [markdown]
# ## Count Holders with balance under threshold

# %%
threshold = 1
under_count = pd_owner[pd_owner["balance"]<=threshold]
under_count
# Out:
#                                         account   balance  counts
# 1    0x2aaba4b94a805f0fea696dc11de324c2320ff4e1  0.000000       1
# 4    0xb7f7f6c52f2e2fdb1963eab30438024864c313f6  0.000000      19
# 6    0x8b6fede39b04c23bfcc7fe74e2680139a68bdbd7  0.310470       1
# 7    0xa9dc1bf6a46bc0d03c2b3d621d434dd6e998190d  0.991008       1
# 9    0xbcd7e572be79a7aa288c35ff6b624da447710107  0.073051       1
# ..                                          ...       ...     ...
# 185  0xa858ddc0445d8131dac4d1de01f834ffcba52ef1  0.022700     116
# 186  0x27f8cf716723daa1dd131f5013fe5352052919b7  0.488651       1
# 191  0x23d23d05eca973294c648be9db31e6e6ae90c0c7  0.165433       1
# 192  0x629d33cc77b19f479218f10752a8aa1b70f0b89a  0.000000       1
# 193  0x35508f0bbb1d02f2fbbeaf6219379dd8ad8e7d92  0.990401       1
#
# [99 rows x 3 columns]

# %%
threshold = 200
over_count = pd_owner[pd_owner["balance"]>threshold]
over_count
# Out:
#                                         account      balance  counts
# 3    0x1919db36ca2fa2e15f9000fd9cdc2edcf863e685   244.941056       6
# 15   0x96e1199931a9e201a4d209262c8c379e2c0e4852   554.599304       1
# 17   0x2503e93fbb53fe9821630746a4070bec2f7d496d   462.026515       1
# 80   0xbb26a6da4d918682f58cc91bd3fb251dd28549d2   410.389711      10
# 85   0x484c6dcd50978b9d525cc20a02d5801f492931f8   219.274267       2
# 103  0x534a0076fb7c2b1f83fa21497429ad7ad3bd7587   280.013514       1
# 105  0xcb9cadd85c510ff5a4fb2d2bb6fb4b74ff3aee34   332.431470       1
# 111  0x7a63bf9561529a64ec8b708b9930dff88e874b5f   252.000000       1
# 147  0x1cf2b8c64aed32bff2ae80e701681316d3212afd   218.669745       1
# 162  0x8bbc693d042cea740e4ff01d7e0efb36110c36bf   300.198435       1
# 166  0xa8d31c4546a782085d81a1ec1598054400d7a2ae   250.081038       2
# 174  0x0f576fe0a916ca39ee929f0cc956cfc9d2a59c12   543.692884       3
# 176  0x64c74b5cfe60cb5f36ddebb14b9431ba33e95527  1067.262352       1
# 183  0xfe2f279d3679bac2d07cf46c93503410ef9ca448   463.775707       1

# %%
Threshold_list = [0, 1, 5, 10, 50, 100, 10000]
stat_dict = []
prev = 0

for threshold in Threshold_list:
    stat_dict.append(np.sum(pd_owner["counts"].loc[pd_owner["balance"]<=threshold]) - prev)
    prev += stat_dict[-1]

# %%
account_pie = pd.DataFrame.from_dict([Threshold_list, stat_dict]).T
account_pie.columns = ["Balance Threshold", "Numbers of NFT"]
account_pie = account_pie.set_index("Balance Threshold")

account_pie.plot.pie(y="Numbers of NFT", figsize=(12,12), autopct='%1.0f%%', title="Account Balance")
# Out:
# <AxesSubplot:title={'center':'Account Balance'}, ylabel='Numbers of NFT'>

# %% [markdown]
# ## Get all NFT's in the interest wallet

# %%
params = {
    'chain': 'eth',
    'format': 'decimal',
}

# %%
interest_address = over_count["account"]
NFT_result_list = []
mapping = {}

""" Get all token of one account """
i = 0
for owner_addr in interest_address:
    url = f"https://deep-index.moralis.io/api/v2/{owner_addr}/nft"
    response = json.loads(requests.get(url, headers=headers, params=params).text)["result"]
    
    for r in response:
        if r["token_address"] in mapping.keys():
            NFT_result_list[mapping[r["token_address"]]]["Numbers"] += 1
        else:
            mapping[r["token_address"]] = i
            i += 1
            tmp = {
                'token_address': r["token_address"],
                'name': r["name"],
                'symbol': r["symbol"],
                'Numbers': 1,
            }
            NFT_result_list.append(tmp)

# %%
# Sort by collection Numbers
NFT_result_list = sorted(NFT_result_list, key=lambda r: r["Numbers"], reverse=True)
NFT_result_list
# Out:
# [{'token_address': '0xc799f57355677a19b91c722734743215513dece5',
#   'name': 'ShatteredEon',
#   'symbol': 'Colonists',
#   'Numbers': 100},
#  {'token_address': '0xb47e3cd837ddf8e4c57f05d70ab865de6e193bbb',
#   'name': 'CRYPTOPUNKS',
#   'symbol': 'Ͼ',
#   'Numbers': 68},
#  {'token_address': '0x4b3406a41399c7fd2ba65cbc93697ad9e7ea61e5',
#   'name': 'Lost Poets',
#   'symbol': 'POETS',
#   'Numbers': 64},
#  {'token_address': '0x495f947276749ce646f68ac8c248420045cb7b5e',
#   'name': 'OpenSea Shared Storefront',
#   'symbol': 'OPENSTORE',
#   'Numbers': 63},
#  {'token_address': '0xba30e5f9bb24caa003e9f2f0497ad287fdf95623',
#   'name': 'BoredApeKennelClub',
#   'symbol': 'BAKC',
#   'Numbers': 57},
#  {'token_address': '0xaf90d15098275db315979b00f8a308c8c0bb980f',
#   'name': 'Gutter Punks Flyer - CryptoPunks',
#   'symbol': 'GPFCP',
#   'Numbers': 54},
#  {'token_address': '0x60e4d786628fea6478f785a6d7e704777c86a7c6',
#   'name': 'MutantApeYachtClub',
#   'symbol': 'MAYC',
#   'Numbers': 54},
#  {'token_address': '0x3b3ee1931dc30c1957379fac9aba94d1c48a5405',
#   'name': 'FND NFT',
#   'symbol': 'FNDNFT',
#   'Numbers': 40},
#  {'token_address': '0x5af0d9827e0c53e4799bb226655a1de152a425a5',
#   'name': 'Milady',
#   'symbol': 'MIL',
#   'Numbers': 40},
#  {'token_address': '0x177ef8787ceb5d4596b6f011df08c86eb84380dc',
#   'name': 'Smilesss',
#   'symbol': 'SMLS',
#   'Numbers': 39},
#  {'token_address': '0x1e0e008eec6d04c52a3945d3df33d04e06a9c46f',
#   'name': 'Gutter Punks Flyer',
#   'symbol': 'GPF',
#   'Numbers': 34},
#  {'token_address': '0xbc4ca0eda7647a8ab7c2061c2e118a18a936f13d',
#   'name': 'BoredApeYachtClub',
#   'symbol': 'BAYC',
#   'Numbers': 32},
#  {'token_address': '0xe3435edbf54b5126e817363900234adfee5b3cee',
#   'name': 'Voxies',
#   'symbol': 'VOXIES',
#   'Numbers': 30},
#  {'token_address': '0x7bd29408f11d2bfc23c34f18275bbf23bb716bc7',
#   'name': 'Meebits',
#   'symbol': '⚇',
#   'Numbers': 26},
#  {'token_address': '0x06b69c1c617a973e0ab91dc66442e97b490aa965',
#   'name': '',
#   'symbol': '',
#   'Numbers': 25},
#  {'token_address': '0x8d768fc1e3af47acc8d8ed5596379ae05310f470',
#   'name': 'CVSpoons',
#   'symbol': 'CVS',
#   'Numbers': 25},
#  {'token_address': '0xef0182dc0574cd5874494a120750fd222fdb909a',
#   'name': 'RumbleKongLeague',
#   'symbol': 'RKL',
#   'Numbers': 24},
#  {'token_address': '0xa7d8d9ef8d8ce8992df33d8b8cf4aebabd5bd270',
#   'name': 'Art Blocks',
#   'symbol': 'BLOCKS',
#   'Numbers': 23},
#  {'token_address': '0x75448243a3ccde04368d2c19a01a710602e5f658',
#   'name': 'BittyBots',
#   'symbol': 'BITTY',
#   'Numbers': 20},
#  {'token_address': '0x1db61fc42a843bad4d91a2d788789ea4055b8613',
#   'name': 'Chubbies',
#   'symbol': 'CHUBBIES',
#   'Numbers': 20},
#  {'token_address': '0xf65bceee9c9ba19e1b88ab901f66a0b4a4a99669',
#   'name': 'SleazySlothSyndicate',
#   'symbol': 'SLOTH',
#   'Numbers': 20},
#  {'token_address': '0xa4d5fb4ff0fa1565fb7d8f5db88e4c0f2f445046',
#   'name': 'Notorious Frogs',
#   'symbol': 'FROGS',
#   'Numbers': 20},
#  {'token_address': '0xa59bb344aeca49c1c910fc9b9e305ce6c10d4e24',
#   'name': 'BoredApes',
#   'symbol': 'BA',
#   'Numbers': 20},
#  {'token_address': '0x57f1887a8bf19b14fc0df6fd9b2acc9af147ea85',
#   'name': 'Ethereum Name Service',
#   'symbol': 'ENS',
#   'Numbers': 19},
#  {'token_address': '0x76be3b62873462d2142405439777e971754e8e77',
#   'name': 'parallel',
#   'symbol': 'LL',
#   'Numbers': 18},
#  {'token_address': '0xfee27fb71ae3feeef2c11f8e02037c42945e87c4',
#   'name': 'Colorverse',
#   'symbol': 'RGB',
#   'Numbers': 17},
#  {'token_address': '0x473fbdf1a797589df54751816623eb037c71ce27',
#   'name': 'Gutter Punks Comic - Flyer',
#   'symbol': 'GPCMAYC',
#   'Numbers': 16},
#  {'token_address': '0x8754f54074400ce745a7ceddc928fb1b7e985ed6',
#   'name': 'EulerBeats',
#   'symbol': 'eBEATS',
#   'Numbers': 15},
#  {'token_address': '0xb932a70a57673d89f4acffbe830e8ed7f75fb9e0',
#   'name': 'SuperRare',
#   'symbol': 'SUPR',
#   'Numbers': 15},
#  {'token_address': '0x5180f2a553e76fac3cf019c8011711cf2b5c6035',
#   'name': 'RKLSneakers',
#   'symbol': 'RKLS',
#   'Numbers': 13},
#  {'token_address': '0x2ac18fcebb80051091ccd3dc3d5ef813d911bbc2',
#   'name': 'The MonstroCities',
#   'symbol': 'MONSTRO',
#   'Numbers': 12},
#  {'token_address': '0x046427fa6b924739cd98ee507cb0db34c7a66c2e',
#   'name': 'Unidentified contract - V7hByRdrhA',
#   'symbol': '',
#   'Numbers': 10},
#  {'token_address': '0xf1268733c6fb05ef6be9cf23d24436dcd6e0b35e',
#   'name': 'Desperate ApeWives',
#   'symbol': 'DAW',
#   'Numbers': 10},
#  {'token_address': '0x0910ec6120316daa6539643474d2087c13f0c494',
#   'name': 'Panda Earth Wrapped',
#   'symbol': 'PEW',
#   'Numbers': 10},
#  {'token_address': '0x24d0cbd0d5d7b50212251c5dc7cb810e7af71f6a',
#   'name': 'Ape Harbour Yachts',
#   'symbol': 'AHY',
#   'Numbers': 9},
#  {'token_address': '0x82c7a8f707110f5fbb16184a5933e9f78a34c6ab',
#   'name': 'Emblem Vault V4',
#   'symbol': 'Emblem.pro',
#   'Numbers': 9},
#  {'token_address': '0x099689220846644f87d1137665cded7bf3422747',
#   'name': 'Robotos',
#   'symbol': 'ROBO',
#   'Numbers': 9},
#  {'token_address': '0xd07dc4262bcdbf85190c01c996b4c06a461d2430',
#   'name': 'Rarible',
#   'symbol': 'RARI',
#   'Numbers': 8},
#  {'token_address': '0x49cf6f5d44e70224e2e23fdcdd2c053f30ada28b',
#   'name': 'CloneX',
#   'symbol': 'CloneX',
#   'Numbers': 8},
#  {'token_address': '0xd8b7cc75e22031a72d7b8393113ef2536e17bde6',
#   'name': 'GEN.ART Drop',
#   'symbol': 'GENART',
#   'Numbers': 7},
#  {'token_address': '0x99c2546aebc070fb1f286a346ec4d25e70533474',
#   'name': 'Quadrums',
#   'symbol': 'QDRMS',
#   'Numbers': 7},
#  {'token_address': '0xff9c1b15b16263c61d017ee9f65c50e4ae0113d7',
#   'name': 'Loot',
#   'symbol': 'LOOT',
#   'Numbers': 7},
#  {'token_address': '0xb4c7f8ce9cd92bccbb0d0a13f9baaf8ed583930c',
#   'name': 'Today',
#   'symbol': 'TODAY',
#   'Numbers': 7},
#  {'token_address': '0x1d20a51f088492a0f1c57f047a9e30c9ab5c07ea',
#   'name': 'loomlocknft',
#   'symbol': 'LL',
#   'Numbers': 7},
#  {'token_address': '0x98b486f4fd2a1526eb6fd09f200735d4a9fcadfa',
#   'name': 'Doodles Flipped',
#   'symbol': 'DOODLESFLIPPED',
#   'Numbers': 6},
#  {'token_address': '0xeff8450c6a69217bf98f95143a8c76166b25164d',
#   'name': 'RosenBigDrop',
#   'symbol': 'Rosen',
#   'Numbers': 6},
#  {'token_address': '0x0540cd12951c6dc3b06bae466914b46dcaa28cf8',
#   'name': 'Gutter Punks Flyer - Meebits',
#   'symbol': 'GPFM',
#   'Numbers': 6},
#  {'token_address': '0xda7d42b6167f1497346d7b2336a6d7a603026db1',
#   'name': None,
#   'symbol': None,
#   'Numbers': 6},
#  {'token_address': '0xe8076b98cd6e4e1018a7208c05e8a8443b0dd35b',
#   'name': 'Ape Harbour Superyachts',
#   'symbol': 'AHSY',
#   'Numbers': 5},
#  {'token_address': '0x6dc6001535e15b9def7b0f6a20a2111dfa9454e2',
#   'name': 'MetaHero',
#   'symbol': 'HERO',
#   'Numbers': 5},
#  {'token_address': '0x65498bf901a0c47ba9507c8a778d2bdee4db12b4',
#   'name': 'Gutter Punks - WoWG',
#   'symbol': 'GPWOWG',
#   'Numbers': 5},
#  {'token_address': '0x85ff6ec2bd7446c90f24f6a5e5acdd82bcd2d4be',
#   'name': 'Gutter Punks - WoW',
#   'symbol': 'GPWOW',
#   'Numbers': 5},
#  {'token_address': '0xf61f24c2d93bf2de187546b14425bf631f28d6dc',
#   'name': 'World Of Women Galaxy',
#   'symbol': 'WOWG',
#   'Numbers': 5},
#  {'token_address': '0xe785e82358879f061bc3dcac6f0444462d4b5330',
#   'name': 'World Of Women',
#   'symbol': 'WOW',
#   'Numbers': 5},
#  {'token_address': '0x09233d553058c2f42ba751c87816a8e9fae7ef10',
#   'name': 'My Pet Hooligan',
#   'symbol': 'MPH',
#   'Numbers': 5},
#  {'token_address': '0x9a534628b4062e123ce7ee2222ec20b86e16ca8f',
#   'name': 'MekaVerse',
#   'symbol': 'MEKA',
#   'Numbers': 5},
#  {'token_address': '0x8479277aacff4663aa4241085a7e27934a0b0840',
#   'name': 'Realms of Ether',
#   'symbol': 'REALM',
#   'Numbers': 5},
#  {'token_address': '0xb8da418ffc2cb675b8b3d73dca0e3f10811fbbdd',
#   'name': 'WE_ARE_KLOUD',
#   'symbol': 'KLOUD',
#   'Numbers': 5},
#  {'token_address': '0x166a0ce5814b5188e9aa96da3dc05a38018fc927',
#   'name': 'The Shark Mob GA',
#   'symbol': 'TSMGA',
#   'Numbers': 5},
#  {'token_address': '0x8eaaabe11896bd09fb852d3a5248004ec44bc793',
#   'name': 'Refractions',
#   'symbol': 'refractions',
#   'Numbers': 4},
#  {'token_address': '0x7deb7bce4d360ebe68278dee6054b882aa62d19c',
#   'name': 'Planets',
#   'symbol': 'PLANET',
#   'Numbers': 4},
#  {'token_address': '0x4eca3d3d8148a181226861bb3ec3514706360362',
#   'name': 'dGenesis dGen Automatons',
#   'symbol': 'DGNA',
#   'Numbers': 4},
#  {'token_address': '0x1f64347b6165ffc9a353ddc97c792401f6d7b121',
#   'name': 'ONE OF ONE',
#   'symbol': 'UNIQUE',
#   'Numbers': 4},
#  {'token_address': '0x78fd3fa3ce045f59eb8c4dc7c21906295a8e3ab4',
#   'name': 'Rich Baby',
#   'symbol': 'BABY',
#   'Numbers': 4},
#  {'token_address': '0xe72f95902854d33b7b75ccc864ff7c76b5f70613',
#   'name': 'MekaBot',
#   'symbol': 'MBOT',
#   'Numbers': 4},
#  {'token_address': '0xc4c6d110226598cd24be9efcd0e094368dd4ed8c',
#   'name': "Troll Fuckin' Tunes",
#   'symbol': 'TUNES',
#   'Numbers': 3},
#  {'token_address': '0x226bf5293692610692e2c996c9875c914d2a7f73',
#   'name': 'oncyber',
#   'symbol': 'oncyber',
#   'Numbers': 3},
#  {'token_address': '0x240eb6b465f61dfc965053791f963cd0f0e4fdb0',
#   'name': 'FuckinTrolls',
#   'symbol': 'FKNTRLLS',
#   'Numbers': 3},
#  {'token_address': '0xafba8c6b3875868a90e5055e791213258a9fe7a7',
#   'name': 'VoxoDeus',
#   'symbol': 'VXO',
#   'Numbers': 3},
#  {'token_address': '0x3bb82ae28ba8d1744e749b54536f7b6e5f56f138',
#   'name': 'MorsEst',
#   'symbol': 'MESP',
#   'Numbers': 3},
#  {'token_address': '0xd4b61ef46ad352ea6b8846180c4fdd59f36056a1',
#   'name': 'Ape Harbour Dinghies',
#   'symbol': 'AHD',
#   'Numbers': 3},
#  {'token_address': '0x375ea781c49eafedde07afe6196f885761f166ae',
#   'name': 'CryptoTrunks',
#   'symbol': 'CT',
#   'Numbers': 3},
#  {'token_address': '0xb32979486938aa9694bfc898f35dbed459f44424',
#   'name': 'Nyan Cat',
#   'symbol': 'NYAN',
#   'Numbers': 3},
#  {'token_address': '0xf8a7d7f7871100d0094f1bfa723de1087e7617c3',
#   'name': 'Sounds of The Blockchain',
#   'symbol': 'SoTB',
#   'Numbers': 3},
#  {'token_address': '0xe18a32192ed95b0fe9d70d19e5025f103475d7ba',
#   'name': 'HASH by POB',
#   'symbol': '',
#   'Numbers': 3},
#  {'token_address': '0x325b07bb7392bdc365e8362dc9546265047bcd4e',
#   'name': 'Sonya_illustration',
#   'symbol': 'SONYAART',
#   'Numbers': 3},
#  {'token_address': '0x4f8730e0b32b04beaa5757e5aea3aef970e5b613',
#   'name': 'Bloot',
#   'symbol': 'BLOOT',
#   'Numbers': 3},
#  {'token_address': '0xf8ef0631aa8150aee8cfb4db3fa27e81d78df620',
#   'name': 'BrokeBoyz',
#   'symbol': 'BBZ',
#   'Numbers': 3},
#  {'token_address': '0xd07e72b00431af84ad438ca995fd9a7f0207542d',
#   'name': 'Hashes',
#   'symbol': 'HASH',
#   'Numbers': 3},
#  {'token_address': '0x1adfe6a7b85e89810e8d10fa60f4637c801d85c3',
#   'name': 'Voyage',
#   'symbol': 'VOYAGE',
#   'Numbers': 3},
#  {'token_address': '0xe01569ca9b39e55bc7c0dfa09f05fa15cb4c7698',
#   'name': 'Gallery Membership Cards',
#   'symbol': 'GMC',
#   'Numbers': 3},
#  {'token_address': '0x79fc737f06c72ca9576822699e8c762d6dd0f768',
#   'name': 'Wanderer',
#   'symbol': 'WANDERER',
#   'Numbers': 3},
#  {'token_address': '0x521f9c7505005cfa19a8e5786a9c3c9c9f5e6f42',
#   'name': 'ForgottenRunesWizardsCult',
#   'symbol': 'WIZARDS',
#   'Numbers': 3},
#  {'token_address': '0x503d73d0008b97ad1516845ef73265e77e6d498f',
#   'name': 'Tsubasa',
#   'symbol': 'TSUBASA',
#   'Numbers': 3},
#  {'token_address': '0xec13de18765b0e65f99f6bfac56a856b90e7f2ab',
#   'name': 'NomadCollection',
#   'symbol': 'NMDC',
#   'Numbers': 3},
#  {'token_address': '0x35e1402fa69c60851ea8b86f04d823ff41796a51',
#   'name': 'ZodiacCapsule',
#   'symbol': 'ZODIACCAPSULE',
#   'Numbers': 3},
#  {'token_address': '0xfcb1315c4273954f74cb16d5b663dbf479eec62e',
#   'name': 'Capsule',
#   'symbol': 'CAPSULE',
#   'Numbers': 3},
#  {'token_address': '0x1d3ada5856b14d9df178ea5cab137d436dc55f1d',
#   'name': 'Deathbats Club',
#   'symbol': 'DBC',
#   'Numbers': 3},
#  {'token_address': '0x7858fe713449bdba2dc9641ecf9defa6b8c0f62a',
#   'name': 'SpaceCowboys',
#   'symbol': 'SC',
#   'Numbers': 2},
#  {'token_address': '0x7ef232e01c45377b0321ff11ca50c59c5b69212b',
#   'name': 'Creep Kids Genesis',
#   'symbol': 'CRK',
#   'Numbers': 2},
#  {'token_address': '0x11e1638d68d4eff1e60dde34710598882ac957c3',
#   'name': 'Holly+ DAO Genesis Token',
#   'symbol': 'HOLLYPLUSDAO',
#   'Numbers': 2},
#  {'token_address': '0x1181eb587073f73b0fe4209d7041015b1d56d59c',
#   'name': 'Colorverse NFWe',
#   'symbol': 'NFWe',
#   'Numbers': 2},
#  {'token_address': '0xd754937672300ae6708a51229112de4017810934',
#   'name': 'Deafbeef',
#   'symbol': 'DEAFBEEF',
#   'Numbers': 2},
#  {'token_address': '0xa98771a46dcb34b34cdad5355718f8a97c8e603e',
#   'name': 'EulerBeats: Enigma',
#   'symbol': 'eBEATS',
#   'Numbers': 2},
#  {'token_address': '0x15f5ee2362f686617ee97c166f8e1b681dda7e8c',
#   'name': 'MemeCalf-NFT',
#   'symbol': 'MemeCalf',
#   'Numbers': 2},
#  {'token_address': '0xb7be4001bff2c5f4a61dd2435e4c9a19d8d12343',
#   'name': None,
#   'symbol': None,
#   'Numbers': 2},
#  {'token_address': '0x86825dfca7a6224cfbd2da48e85df2fc3aa7c4b1',
#   'name': 'RTFKT',
#   'symbol': 'RTFKT',
#   'Numbers': 2},
#  {'token_address': '0xc2e9678a71e50e5aed036e00e9c5caeb1ac5987d',
#   'name': 'Zero Name Service',
#   'symbol': 'zNS',
#   'Numbers': 2},
#  {'token_address': '0xede64feff210f406bff709e2f375611641c2a945',
#   'name': 'cLoot.org',
#   'symbol': 'CLOOT',
#   'Numbers': 2},
#  {'token_address': '0x0db9e2f4395a179e4add26b43cfe8e4ea1830b46',
#   'name': 'Tweet DAO Eggs',
#   'symbol': 'TWEETDAO',
#   'Numbers': 2},
#  {'token_address': '0xa8ea63d5bfd1a133fc6149a77d0fe29943a02d5e',
#   'name': 'Melancholy',
#   'symbol': 'MLNCHL',
#   'Numbers': 2},
#  {'token_address': '0x79336dab932b6d7951006ea5a394cf580246822f',
#   'name': 'Curio Remix #2',
#   'symbol': 'crx2',
#   'Numbers': 2},
#  {'token_address': '0x682ffe8a00461b727d6772e9faa8cfe6d341de09',
#   'name': 'A pulse in stillness',
#   'symbol': 'PULSE',
#   'Numbers': 2},
#  {'token_address': '0x6bab7e940d7f3032d2ae24b9bc7c6ed0eae31292',
#   'name': 'Portraits ',
#   'symbol': 'YELLOW',
#   'Numbers': 2},
#  {'token_address': '0x2963ba471e265e5f51cafafca78310fe87f8e6d1',
#   'name': 'MakersPlace',
#   'symbol': 'MAKERS',
#   'Numbers': 2},
#  {'token_address': '0x5755ab845ddeab27e1cfce00cd629b2e135acc3d',
#   'name': 'Larva Lads',
#   'symbol': 'LARVA',
#   'Numbers': 2},
#  {'token_address': '0xf152e743a6773fc65d3ec1a4e10db5da7d249d29',
#   'name': 'Luxeto Punk Sneaker',
#   'symbol': 'LPSD',
#   'Numbers': 2},
#  {'token_address': '0xb66a603f4cfe17e3d27b87a8bfcad319856518b8',
#   'name': 'Rarible',
#   'symbol': 'RARI',
#   'Numbers': 2},
#  {'token_address': '0x8f4ca9a9df620ac58152f5369650dbccd006de37',
#   'name': 'Rollbit VIP Passes',
#   'symbol': 'ROLLBITVIPPASS',
#   'Numbers': 2},
#  {'token_address': '0xe12dcd9cf652c8f0d9bfb5666a0abef17c3c8f4e',
#   'name': 'JetPackCat',
#   'symbol': 'JPC',
#   'Numbers': 2},
#  {'token_address': '0x21bf3da0cf0f28da27169239102e26d3d46956e5',
#   'name': 'Monaco Planet',
#   'symbol': 'MONA',
#   'Numbers': 2},
#  {'token_address': '0x9c8ff314c9bc7f6e59a9d9225fb22946427edc03',
#   'name': 'Nouns',
#   'symbol': 'NOUN',
#   'Numbers': 2},
#  {'token_address': '0x1dfe7ca09e99d10835bf73044a23b73fc20623df',
#   'name': 'More Loot',
#   'symbol': 'MLOOT',
#   'Numbers': 2},
#  {'token_address': '0xca7ca7bcc765f77339be2d648ba53ce9c8a262bd',
#   'name': 'Tubby Cats',
#   'symbol': 'TUBBY',
#   'Numbers': 2},
#  {'token_address': '0xb55b7e00152d2ef27357944a96f29271f8073f11',
#   'name': 'CryptoCatPunks by Studio Moduler',
#   'symbol': 'CCP',
#   'Numbers': 1},
#  {'token_address': '0x33b39ad6bea0c5fd084dae8066bc3165678c4328',
#   'name': 'UNTAMED SOULS',
#   'symbol': 'US',
#   'Numbers': 1},
#  {'token_address': '0x50842cd03177aee608840a659768c55a5405ac46',
#   'name': 'Cyber Wolves',
#   'symbol': 'CW',
#   'Numbers': 1},
#  {'token_address': '0xcfff4c8c0df0e2431977eba7df3d3de857f4b76e',
#   'name': 'RiverMen',
#   'symbol': 'RM',
#   'Numbers': 1},
#  {'token_address': '0x4b16a470ecabfbb565f77b0730bee4fb6d02f9f6',
#   'name': 'DeNations Art Open Edition',
#   'symbol': 'DARTO',
#   'Numbers': 1},
#  {'token_address': '0x462faa2995b80fbc8a3b39d24b0a9929e95a1d1f',
#   'name': 'CrazyCyberBunny',
#   'symbol': 'CCB',
#   'Numbers': 1},
#  {'token_address': '0x33cfae13a9486c29cd3b11391cc7eca53822e8c7',
#   'name': 'MintPass 2',
#   'symbol': 'PASS2',
#   'Numbers': 1},
#  {'token_address': '0x0e7fb4c55d63901fb855da2d8c6a1d6941c4a77f',
#   'name': None,
#   'symbol': None,
#   'Numbers': 1},
#  {'token_address': '0xb305904aab1d1041b9c237e46a68fc9a22d60bc2',
#   'name': '',
#   'symbol': '',
#   'Numbers': 1},
#  {'token_address': '0xa7206d878c5c3871826dfdb42191c49b1d11f466',
#   'name': 'LOSTPOETS',
#   'symbol': '',
#   'Numbers': 1},
#  {'token_address': '0xbbfb6e466f376e493da35b5665dbfc19f7204231',
#   'name': 'GEN.ART Collection',
#   'symbol': 'GENART',
#   'Numbers': 1},
#  {'token_address': '0x1ca39c7f0f65b4da24b094a9afac7acf626b7f38',
#   'name': 'GEN.ART',
#   'symbol': 'GA',
#   'Numbers': 1},
#  {'token_address': '0xc58d5ec9b31516321cad1d0cfd4020545843606a',
#   'name': 'EulerBeats Wearables',
#   'symbol': '',
#   'Numbers': 1},
#  {'token_address': '0x247e5c7b8279fd8fa94ab7fd48957c5bbf9762eb',
#   'name': 'WHOLENESS by SMECCEA',
#   'symbol': 'WHOLENESSBYSMECCEA',
#   'Numbers': 1},
#  {'token_address': '0x7d256d82b32d8003d1ca1a1526ed211e6e0da9e2',
#   'name': 'Yat NFT',
#   'symbol': 'Yats',
#   'Numbers': 1},
#  {'token_address': '0xc86ca2bb9c9c9c9f140d832de00bfa9e153fa1e3',
#   'name': 'Cyber Curated',
#   'symbol': '',
#   'Numbers': 1},
#  {'token_address': '0x6f0365ca2c1dd63473f898a60f878a07e0f68a26',
#   'name': 'TopDogBeachClub',
#   'symbol': 'TDBC',
#   'Numbers': 1},
#  {'token_address': '0x5b8773b544ec3b7d0215ec34861f1d8eaec60949',
#   'name': 'Eulerbeat Dreams Coverart & Mp3',
#   'symbol': 'EBDC',
#   'Numbers': 1},
#  {'token_address': '0x60f80121c31a0d46b5279700f9df786054aa5ee5',
#   'name': 'Rarible',
#   'symbol': 'RARI',
#   'Numbers': 1},
#  {'token_address': '0xd46939da978d70f8564fccd1965df257aa8fd726',
#   'name': 'LP07 Album Cover Art',
#   'symbol': 'LP07',
#   'Numbers': 1},
#  {'token_address': '0xf4680c917a873e2dd6ead72f9f433e74eb9c623c',
#   'name': 'Twerky Bags',
#   'symbol': 'TWYBGS',
#   'Numbers': 1},
#  {'token_address': '0x50f5474724e0ee42d9a4e711ccfb275809fd6d4a',
#   'name': "Sandbox's LANDs",
#   'symbol': 'LAND',
#   'Numbers': 1},
#  {'token_address': '0xd0b53410454370a482979c0adaf3667c6308a801',
#   'name': 'Elite Ape Entry Coins',
#   'symbol': 'COINS',
#   'Numbers': 1},
#  {'token_address': '0x28472a58a490c5e09a238847f66a68a47cc76f0f',
#   'name': 'adidas Originals: Into the Metaverse',
#   'symbol': 'ADI',
#   'Numbers': 1},
#  {'token_address': '0x22c36bfdcef207f9c0cc941936eff94d4246d14a',
#   'name': '',
#   'symbol': '',
#   'Numbers': 1},
#  {'token_address': '0x341a1c534248966c4b6afad165b98daed4b964ef',
#   'name': 'Murakami.Flowers Seed',
#   'symbol': 'SEED',
#   'Numbers': 1},
#  {'token_address': '0xa2689f62d0e362607d5fad4e1798e0c2bcaef07c',
#   'name': 'Gutter Punks Flyer - Cool Cats',
#   'symbol': 'GPFCC',
#   'Numbers': 1},
#  {'token_address': '0xd4f3a00b470c9ed76510cc92fd07e59e0a5c34d1',
#   'name': 'Gutter Punks',
#   'symbol': 'GPFCT',
#   'Numbers': 1},
#  {'token_address': '0x52607cb9c342821ea41ad265b9bb6a23bea49468',
#   'name': 'Flowtys',
#   'symbol': 'FLOWTY',
#   'Numbers': 1},
#  {'token_address': '0x1a92f7381b9f03921564a437210bb9396471050c',
#   'name': 'Cool Cats',
#   'symbol': 'COOL',
#   'Numbers': 1},
#  {'token_address': '0x1cb1a5e65610aeff2551a50f76a87a7d3fb649c6',
#   'name': 'Cryptoadz',
#   'symbol': 'TOADZ',
#   'Numbers': 1},
#  {'token_address': '0x80656ae3214d203d6dede78e1c5846857da64d6e',
#   'name': 'Proof of Rock',
#   'symbol': 'POR',
#   'Numbers': 1},
#  {'token_address': '0x8707276df042e89669d69a177d3da7dc78bd8723',
#   'name': 'DOPE',
#   'symbol': 'DOPE',
#   'Numbers': 1},
#  {'token_address': '0x33a4cfc925ad40e5bb2b9b2462d7a1a5a5da4476',
#   'name': '',
#   'symbol': '',
#   'Numbers': 1},
#  {'token_address': '0x343f999eaacdfa1f201fb8e43ebb35c99d9ae0c1',
#   'name': 'Loneley Aliens Space Club',
#   'symbol': 'LASC',
#   'Numbers': 1},
#  {'token_address': '0xbd3531da5cf5857e7cfaa92426877b022e612cf8',
#   'name': 'PudgyPenguins',
#   'symbol': 'PPG',
#   'Numbers': 1},
#  {'token_address': '0xc29f508c87424dfdff6c618d705ddb18c5228149',
#   'name': 'PURPLE SONDER',
#   'symbol': 'AELRIC',
#   'Numbers': 1},
#  {'token_address': '0xc485cba784d6065bbd4d2ac7e4b176f500b10c01',
#   'name': 'painful bliss.',
#   'symbol': 'PAIN',
#   'Numbers': 1},
#  {'token_address': '0x3fc2620216c442a1566856707ebe9cdf99f21a7c',
#   'name': 'The 0010 Works',
#   'symbol': '0010',
#   'Numbers': 1},
#  {'token_address': '0xa14938e1c098dac404608dfe741a50b79a23911c',
#   'name': None,
#   'symbol': None,
#   'Numbers': 1},
#  {'token_address': '0x8086798d76b63ab999b852a1e75c6c38822a764f',
#   'name': 'LONELINESS AS A WAY OF LIFE',
#   'symbol': 'LNLNSS',
#   'Numbers': 1},
#  {'token_address': '0x1654ea7adcf1c40b9f8fffacfa7118c16f45009c',
#   'name': 'Evening Sun',
#   'symbol': 'SUN',
#   'Numbers': 1},
#  {'token_address': '0xe51e627fbd4a81d42d5e43c926388c34060b91b1',
#   'name': 'Anatomy of Nature fig.3',
#   'symbol': 'SPLIT',
#   'Numbers': 1},
#  {'token_address': '0x1c60df38ce83e7500efbe270285a944c6d03cca5',
#   'name': 'Inception',
#   'symbol': 'ART',
#   'Numbers': 1},
#  {'token_address': '0xd61709c390797bc752e4123febe15a15f481e2ed',
#   'name': 'The Refriedspinach Collection',
#   'symbol': 'TRC',
#   'Numbers': 1},
#  {'token_address': '0x049e959f152b3dec3d1f5e61d3d1f3c371d5fb10',
#   'name': 'badbird',
#   'symbol': 'BDBRD',
#   'Numbers': 1},
#  {'token_address': '0x4a5fa827f409ad245a29824fba3cbc19ee9cc186',
#   'name': 'Illustrated Portraits',
#   'symbol': 'PORTRAIT',
#   'Numbers': 1},
#  {'token_address': '0xe1c30894a8ff005de7993a333f96e7f5c6034371',
#   'name': 'A.Mashiro',
#   'symbol': 'AMSR',
#   'Numbers': 1},
#  {'token_address': '0xbabd0886790027aa6ad1659f6e8bb191898349be',
#   'name': 'Collaborations',
#   'symbol': 'COLLAB',
#   'Numbers': 1},
#  {'token_address': '0xa4acbbbbf68b255b4aef4d5553fd16c13da543a1',
#   'name': 'Lost In A Place',
#   'symbol': 'LOST',
#   'Numbers': 1},
#  {'token_address': '0x21ae76b5672431a9d145452ca0cf441bb0cdb646',
#   'name': 'Fantastical Surreal ',
#   'symbol': 'FS',
#   'Numbers': 1},
#  {'token_address': '0x7b91d14a4688340fdaf2f0be99843bb0fa6b5b4a',
#   'name': 'ƧUЯRΞΛL ЯΞΛLITY',
#   'symbol': 'SR',
#   'Numbers': 1},
#  {'token_address': '0x81e2ca667b0dabd86b1457fab8e1d7eecf53ab47',
#   'name': 'Ink Visions',
#   'symbol': 'INK',
#   'Numbers': 1},
#  {'token_address': '0x9d90308d16b94c38048c782bdd8104a964758a23',
#   'name': 'fees.wtf NFT',
#   'symbol': 'fees.wtf',
#   'Numbers': 1},
#  {'token_address': '0x7eef591a6cc0403b9652e98e88476fe1bf31ddeb',
#   'name': '',
#   'symbol': '',
#   'Numbers': 1},
#  {'token_address': '0x5537d90a4a2dc9d9b37bab49b490cf67d4c54e91',
#   'name': 'OneDayPunk',
#   'symbol': 'ODP',
#   'Numbers': 1},
#  {'token_address': '0xd1e5b0ff1287aa9f9a268759062e4ab08b9dacbe',
#   'name': '.crypto',
#   'symbol': 'UD',
#   'Numbers': 1},
#  {'token_address': '0xca98fdf936243edc3bbd65dc1dcc386ec7a7d540',
#   'name': 'BAYC X OTHERSIDE LAND',
#   'symbol': 'BYOL',
#   'Numbers': 1},
#  {'token_address': '0x39cda2184e833c92badd4b7806d923ba9af53866',
#   'name': 'Big Cats TYG',
#   'symbol': 'BCT',
#   'Numbers': 1},
#  {'token_address': '0x0e1f990d264a9818460dde1b81c0b04d8a88e751',
#   'name': 'TIMEPieces x Robotos',
#   'symbol': None,
#   'Numbers': 1},
#  {'token_address': '0xd1146680ae5a4d71f68accb6610030ced7e7afe1',
#   'name': 'MUTANT PUNKS CITY',
#   'symbol': 'MPC',
#   'Numbers': 1},
#  {'token_address': '0xf55dd62034b534e71cb17ef6e2bb112e93d6131a',
#   'name': 'HIDDEN IN NOISE',
#   'symbol': 'HID',
#   'Numbers': 1},
#  {'token_address': '0x4f9835dbb442b263bbd20ff2731162101d9c3a89',
#   'name': 'Toad Punks',
#   'symbol': 'tdpnks',
#   'Numbers': 1},
#  {'token_address': '0x0406db8351aa6839169bb363f63c2c808fee8f99',
#   'name': 'Cobo 4th Anniversary NFT',
#   'symbol': 'C4A',
#   'Numbers': 1},
#  {'token_address': '0x620de236fcce1e061725f382be3d1bf689f29a5c',
#   'name': 'Lulupunk',
#   'symbol': 'LLPK',
#   'Numbers': 1},
#  {'token_address': '0x45843e61a956cf262a8899a24889c41a5c209662',
#   'name': 'CryptoKlaus',
#   'symbol': 'CK',
#   'Numbers': 1},
#  {'token_address': '0x9523b6429924e4fac50568572cf1d24697190c1d',
#   'name': 'Magnum',
#   'symbol': 'MAGNUM',
#   'Numbers': 1},
#  {'token_address': '0x0c6218d95735d3e12ae7c4703106e4b8e0b61010',
#   'name': 'Purrnelopes Kittens',
#   'symbol': 'PK',
#   'Numbers': 1},
#  {'token_address': '0x7daec605e9e2a1717326eedfd660601e2753a057',
#   'name': None,
#   'symbol': None,
#   'Numbers': 1},
#  {'token_address': '0xd4e4078ca3495de5b1d4db434bebc5a986197782',
#   'name': 'Autoglyphs',
#   'symbol': '☵',
#   'Numbers': 1},
#  {'token_address': '0x9759226b2f8ddeff81583e244ef3bd13aaa7e4a1',
#   'name': 'Purrnelopes Country Club',
#   'symbol': 'PCC',
#   'Numbers': 1},
#  {'token_address': '0x0cfb5d82be2b949e8fa73a656df91821e2ad99fd',
#   'name': '10KTF',
#   'symbol': '10KTF',
#   'Numbers': 1},
#  {'token_address': '0x059edd72cd353df5106d2b9cc5ab83a52287ac3a',
#   'name': 'Art Blocks',
#   'symbol': 'BLOCKS',
#   'Numbers': 1}]

# %% [markdown]
# ## Add Lowest Prices to list

# %%
price_params = {
    'chain': 'eth',
    'marketplace': 'opensea',
    'days': 15
}

# %%
for r in NFT_result_list:
    price_url = f"https://deep-index.moralis.io/api/v2/nft/{r['token_address']}/lowestprice"
    price_response = requests.get(price_url, headers=headers, params=price_params)
    if price_response.status_code == 200:
        price_response = json.loads(price_response.text)
        price = float(price_response["price"])/ 1e18
        r['price'] = price
    else:
        r['price'] = 0

# %%
# Sort by value
NFT_result_list = sorted(NFT_result_list, key = lambda r: r['Numbers']*r['price'], reverse = True)
NFT_result_list
# Out:
# [{'token_address': '0xbc4ca0eda7647a8ab7c2061c2e118a18a936f13d',
#   'name': 'BoredApeYachtClub',
#   'symbol': 'BAYC',
#   'Numbers': 32,
#   'price': 96.5},
#  {'token_address': '0xd4e4078ca3495de5b1d4db434bebc5a986197782',
#   'name': 'Autoglyphs',
#   'symbol': '☵',
#   'Numbers': 1,
#   'price': 172.0},
#  {'token_address': '0x9c8ff314c9bc7f6e59a9d9225fb22946427edc03',
#   'name': 'Nouns',
#   'symbol': 'NOUN',
#   'Numbers': 2,
#   'price': 60.0},
#  {'token_address': '0x49cf6f5d44e70224e2e23fdcdd2c053f30ada28b',
#   'name': 'CloneX',
#   'symbol': 'CloneX',
#   'Numbers': 8,
#   'price': 13.0},
#  {'token_address': '0x7bd29408f11d2bfc23c34f18275bbf23bb716bc7',
#   'name': 'Meebits',
#   'symbol': '⚇',
#   'Numbers': 26,
#   'price': 2.6959},
#  {'token_address': '0xe785e82358879f061bc3dcac6f0444462d4b5330',
#   'name': 'World Of Women',
#   'symbol': 'WOW',
#   'Numbers': 5,
#   'price': 7.7},
#  {'token_address': '0x8479277aacff4663aa4241085a7e27934a0b0840',
#   'name': 'Realms of Ether',
#   'symbol': 'REALM',
#   'Numbers': 5,
#   'price': 6.25},
#  {'token_address': '0x177ef8787ceb5d4596b6f011df08c86eb84380dc',
#   'name': 'Smilesss',
#   'symbol': 'SMLS',
#   'Numbers': 39,
#   'price': 0.8},
#  {'token_address': '0x22c36bfdcef207f9c0cc941936eff94d4246d14a',
#   'name': '',
#   'symbol': '',
#   'Numbers': 1,
#   'price': 30.0},
#  {'token_address': '0xef0182dc0574cd5874494a120750fd222fdb909a',
#   'name': 'RumbleKongLeague',
#   'symbol': 'RKL',
#   'Numbers': 24,
#   'price': 1.0},
#  {'token_address': '0x6dc6001535e15b9def7b0f6a20a2111dfa9454e2',
#   'name': 'MetaHero',
#   'symbol': 'HERO',
#   'Numbers': 5,
#   'price': 3.8},
#  {'token_address': '0x8754f54074400ce745a7ceddc928fb1b7e985ed6',
#   'name': 'EulerBeats',
#   'symbol': 'eBEATS',
#   'Numbers': 15,
#   'price': 1.0},
#  {'token_address': '0xba30e5f9bb24caa003e9f2f0497ad287fdf95623',
#   'name': 'BoredApeKennelClub',
#   'symbol': 'BAKC',
#   'Numbers': 57,
#   'price': 0.19},
#  {'token_address': '0xff9c1b15b16263c61d017ee9f65c50e4ae0113d7',
#   'name': 'Loot',
#   'symbol': 'LOOT',
#   'Numbers': 7,
#   'price': 1.4},
#  {'token_address': '0xe3435edbf54b5126e817363900234adfee5b3cee',
#   'name': 'Voxies',
#   'symbol': 'VOXIES',
#   'Numbers': 30,
#   'price': 0.25},
#  {'token_address': '0x1a92f7381b9f03921564a437210bb9396471050c',
#   'name': 'Cool Cats',
#   'symbol': 'COOL',
#   'Numbers': 1,
#   'price': 7.42},
#  {'token_address': '0x5af0d9827e0c53e4799bb226655a1de152a425a5',
#   'name': 'Milady',
#   'symbol': 'MIL',
#   'Numbers': 40,
#   'price': 0.18},
#  {'token_address': '0x521f9c7505005cfa19a8e5786a9c3c9c9f5e6f42',
#   'name': 'ForgottenRunesWizardsCult',
#   'symbol': 'WIZARDS',
#   'Numbers': 3,
#   'price': 1.95},
#  {'token_address': '0xc799f57355677a19b91c722734743215513dece5',
#   'name': 'ShatteredEon',
#   'symbol': 'Colonists',
#   'Numbers': 100,
#   'price': 0.05},
#  {'token_address': '0x341a1c534248966c4b6afad165b98daed4b964ef',
#   'name': 'Murakami.Flowers Seed',
#   'symbol': 'SEED',
#   'Numbers': 1,
#   'price': 5.0},
#  {'token_address': '0x09233d553058c2f42ba751c87816a8e9fae7ef10',
#   'name': 'My Pet Hooligan',
#   'symbol': 'MPH',
#   'Numbers': 5,
#   'price': 0.9},
#  {'token_address': '0x79336dab932b6d7951006ea5a394cf580246822f',
#   'name': 'Curio Remix #2',
#   'symbol': 'crx2',
#   'Numbers': 2,
#   'price': 1.5},
#  {'token_address': '0x059edd72cd353df5106d2b9cc5ab83a52287ac3a',
#   'name': 'Art Blocks',
#   'symbol': 'BLOCKS',
#   'Numbers': 1,
#   'price': 2.99},
#  {'token_address': '0x1d20a51f088492a0f1c57f047a9e30c9ab5c07ea',
#   'name': 'loomlocknft',
#   'symbol': 'LL',
#   'Numbers': 7,
#   'price': 0.4},
#  {'token_address': '0xfcb1315c4273954f74cb16d5b663dbf479eec62e',
#   'name': 'Capsule',
#   'symbol': 'CAPSULE',
#   'Numbers': 3,
#   'price': 0.9},
#  {'token_address': '0x1cb1a5e65610aeff2551a50f76a87a7d3fb649c6',
#   'name': 'Cryptoadz',
#   'symbol': 'TOADZ',
#   'Numbers': 1,
#   'price': 2.7},
#  {'token_address': '0xb32979486938aa9694bfc898f35dbed459f44424',
#   'name': 'Nyan Cat',
#   'symbol': 'NYAN',
#   'Numbers': 3,
#   'price': 0.8},
#  {'token_address': '0xa59bb344aeca49c1c910fc9b9e305ce6c10d4e24',
#   'name': 'BoredApes',
#   'symbol': 'BA',
#   'Numbers': 20,
#   'price': 0.1},
#  {'token_address': '0xf1268733c6fb05ef6be9cf23d24436dcd6e0b35e',
#   'name': 'Desperate ApeWives',
#   'symbol': 'DAW',
#   'Numbers': 10,
#   'price': 0.199},
#  {'token_address': '0x1e0e008eec6d04c52a3945d3df33d04e06a9c46f',
#   'name': 'Gutter Punks Flyer',
#   'symbol': 'GPF',
#   'Numbers': 34,
#   'price': 0.05},
#  {'token_address': '0x226bf5293692610692e2c996c9875c914d2a7f73',
#   'name': 'oncyber',
#   'symbol': 'oncyber',
#   'Numbers': 3,
#   'price': 0.55},
#  {'token_address': '0xb932a70a57673d89f4acffbe830e8ed7f75fb9e0',
#   'name': 'SuperRare',
#   'symbol': 'SUPR',
#   'Numbers': 15,
#   'price': 0.11},
#  {'token_address': '0x9a534628b4062e123ce7ee2222ec20b86e16ca8f',
#   'name': 'MekaVerse',
#   'symbol': 'MEKA',
#   'Numbers': 5,
#   'price': 0.3},
#  {'token_address': '0x78fd3fa3ce045f59eb8c4dc7c21906295a8e3ab4',
#   'name': 'Rich Baby',
#   'symbol': 'BABY',
#   'Numbers': 4,
#   'price': 0.3},
#  {'token_address': '0xb7be4001bff2c5f4a61dd2435e4c9a19d8d12343',
#   'name': None,
#   'symbol': None,
#   'Numbers': 2,
#   'price': 0.568},
#  {'token_address': '0x5180f2a553e76fac3cf019c8011711cf2b5c6035',
#   'name': 'RKLSneakers',
#   'symbol': 'RKLS',
#   'Numbers': 13,
#   'price': 0.085},
#  {'token_address': '0x0910ec6120316daa6539643474d2087c13f0c494',
#   'name': 'Panda Earth Wrapped',
#   'symbol': 'PEW',
#   'Numbers': 10,
#   'price': 0.11},
#  {'token_address': '0x33a4cfc925ad40e5bb2b9b2462d7a1a5a5da4476',
#   'name': '',
#   'symbol': '',
#   'Numbers': 1,
#   'price': 1.1},
#  {'token_address': '0xb4c7f8ce9cd92bccbb0d0a13f9baaf8ed583930c',
#   'name': 'Today',
#   'symbol': 'TODAY',
#   'Numbers': 7,
#   'price': 0.15},
#  {'token_address': '0x28472a58a490c5e09a238847f66a68a47cc76f0f',
#   'name': 'adidas Originals: Into the Metaverse',
#   'symbol': 'ADI',
#   'Numbers': 1,
#   'price': 1.04},
#  {'token_address': '0x86825dfca7a6224cfbd2da48e85df2fc3aa7c4b1',
#   'name': 'RTFKT',
#   'symbol': 'RTFKT',
#   'Numbers': 2,
#   'price': 0.5},
#  {'token_address': '0x1db61fc42a843bad4d91a2d788789ea4055b8613',
#   'name': 'Chubbies',
#   'symbol': 'CHUBBIES',
#   'Numbers': 20,
#   'price': 0.048},
#  {'token_address': '0xbd3531da5cf5857e7cfaa92426877b022e612cf8',
#   'name': 'PudgyPenguins',
#   'symbol': 'PPG',
#   'Numbers': 1,
#   'price': 0.93},
#  {'token_address': '0x35e1402fa69c60851ea8b86f04d823ff41796a51',
#   'name': 'ZodiacCapsule',
#   'symbol': 'ZODIACCAPSULE',
#   'Numbers': 3,
#   'price': 0.245},
#  {'token_address': '0x099689220846644f87d1137665cded7bf3422747',
#   'name': 'Robotos',
#   'symbol': 'ROBO',
#   'Numbers': 9,
#   'price': 0.079},
#  {'token_address': '0xc2e9678a71e50e5aed036e00e9c5caeb1ac5987d',
#   'name': 'Zero Name Service',
#   'symbol': 'zNS',
#   'Numbers': 2,
#   'price': 0.35},
#  {'token_address': '0xf61f24c2d93bf2de187546b14425bf631f28d6dc',
#   'name': 'World Of Women Galaxy',
#   'symbol': 'WOWG',
#   'Numbers': 5,
#   'price': 0.1366},
#  {'token_address': '0x0db9e2f4395a179e4add26b43cfe8e4ea1830b46',
#   'name': 'Tweet DAO Eggs',
#   'symbol': 'TWEETDAO',
#   'Numbers': 2,
#   'price': 0.3},
#  {'token_address': '0xe01569ca9b39e55bc7c0dfa09f05fa15cb4c7698',
#   'name': 'Gallery Membership Cards',
#   'symbol': 'GMC',
#   'Numbers': 3,
#   'price': 0.164},
#  {'token_address': '0x0406db8351aa6839169bb363f63c2c808fee8f99',
#   'name': 'Cobo 4th Anniversary NFT',
#   'symbol': 'C4A',
#   'Numbers': 1,
#   'price': 0.4},
#  {'token_address': '0x2ac18fcebb80051091ccd3dc3d5ef813d911bbc2',
#   'name': 'The MonstroCities',
#   'symbol': 'MONSTRO',
#   'Numbers': 12,
#   'price': 0.03},
#  {'token_address': '0x8d768fc1e3af47acc8d8ed5596379ae05310f470',
#   'name': 'CVSpoons',
#   'symbol': 'CVS',
#   'Numbers': 25,
#   'price': 0.014},
#  {'token_address': '0x503d73d0008b97ad1516845ef73265e77e6d498f',
#   'name': 'Tsubasa',
#   'symbol': 'TSUBASA',
#   'Numbers': 3,
#   'price': 0.1},
#  {'token_address': '0x24d0cbd0d5d7b50212251c5dc7cb810e7af71f6a',
#   'name': 'Ape Harbour Yachts',
#   'symbol': 'AHY',
#   'Numbers': 9,
#   'price': 0.029},
#  {'token_address': '0xafba8c6b3875868a90e5055e791213258a9fe7a7',
#   'name': 'VoxoDeus',
#   'symbol': 'VXO',
#   'Numbers': 3,
#   'price': 0.08},
#  {'token_address': '0xf65bceee9c9ba19e1b88ab901f66a0b4a4a99669',
#   'name': 'SleazySlothSyndicate',
#   'symbol': 'SLOTH',
#   'Numbers': 20,
#   'price': 0.01},
#  {'token_address': '0xb8da418ffc2cb675b8b3d73dca0e3f10811fbbdd',
#   'name': 'WE_ARE_KLOUD',
#   'symbol': 'KLOUD',
#   'Numbers': 5,
#   'price': 0.04},
#  {'token_address': '0x1654ea7adcf1c40b9f8fffacfa7118c16f45009c',
#   'name': 'Evening Sun',
#   'symbol': 'SUN',
#   'Numbers': 1,
#   'price': 0.2},
#  {'token_address': '0x7eef591a6cc0403b9652e98e88476fe1bf31ddeb',
#   'name': '',
#   'symbol': '',
#   'Numbers': 1,
#   'price': 0.2},
#  {'token_address': '0xf55dd62034b534e71cb17ef6e2bb112e93d6131a',
#   'name': 'HIDDEN IN NOISE',
#   'symbol': 'HID',
#   'Numbers': 1,
#   'price': 0.199},
#  {'token_address': '0xe72f95902854d33b7b75ccc864ff7c76b5f70613',
#   'name': 'MekaBot',
#   'symbol': 'MBOT',
#   'Numbers': 4,
#   'price': 0.04},
#  {'token_address': '0xec13de18765b0e65f99f6bfac56a856b90e7f2ab',
#   'name': 'NomadCollection',
#   'symbol': 'NMDC',
#   'Numbers': 3,
#   'price': 0.05},
#  {'token_address': '0x5755ab845ddeab27e1cfce00cd629b2e135acc3d',
#   'name': 'Larva Lads',
#   'symbol': 'LARVA',
#   'Numbers': 2,
#   'price': 0.069},
#  {'token_address': '0xa7206d878c5c3871826dfdb42191c49b1d11f466',
#   'name': 'LOSTPOETS',
#   'symbol': '',
#   'Numbers': 1,
#   'price': 0.11},
#  {'token_address': '0xe8076b98cd6e4e1018a7208c05e8a8443b0dd35b',
#   'name': 'Ape Harbour Superyachts',
#   'symbol': 'AHSY',
#   'Numbers': 5,
#   'price': 0.02},
#  {'token_address': '0x33cfae13a9486c29cd3b11391cc7eca53822e8c7',
#   'name': 'MintPass 2',
#   'symbol': 'PASS2',
#   'Numbers': 1,
#   'price': 0.099},
#  {'token_address': '0xf4680c917a873e2dd6ead72f9f433e74eb9c623c',
#   'name': 'Twerky Bags',
#   'symbol': 'TWYBGS',
#   'Numbers': 1,
#   'price': 0.085},
#  {'token_address': '0x4b16a470ecabfbb565f77b0730bee4fb6d02f9f6',
#   'name': 'DeNations Art Open Edition',
#   'symbol': 'DARTO',
#   'Numbers': 1,
#   'price': 0.08},
#  {'token_address': '0x21bf3da0cf0f28da27169239102e26d3d46956e5',
#   'name': 'Monaco Planet',
#   'symbol': 'MONA',
#   'Numbers': 2,
#   'price': 0.038},
#  {'token_address': '0xe18a32192ed95b0fe9d70d19e5025f103475d7ba',
#   'name': 'HASH by POB',
#   'symbol': '',
#   'Numbers': 3,
#   'price': 0.024},
#  {'token_address': '0x375ea781c49eafedde07afe6196f885761f166ae',
#   'name': 'CryptoTrunks',
#   'symbol': 'CT',
#   'Numbers': 3,
#   'price': 0.0219},
#  {'token_address': '0xcfff4c8c0df0e2431977eba7df3d3de857f4b76e',
#   'name': 'RiverMen',
#   'symbol': 'RM',
#   'Numbers': 1,
#   'price': 0.065},
#  {'token_address': '0xe12dcd9cf652c8f0d9bfb5666a0abef17c3c8f4e',
#   'name': 'JetPackCat',
#   'symbol': 'JPC',
#   'Numbers': 2,
#   'price': 0.029},
#  {'token_address': '0xf8ef0631aa8150aee8cfb4db3fa27e81d78df620',
#   'name': 'BrokeBoyz',
#   'symbol': 'BBZ',
#   'Numbers': 3,
#   'price': 0.019},
#  {'token_address': '0x8707276df042e89669d69a177d3da7dc78bd8723',
#   'name': 'DOPE',
#   'symbol': 'DOPE',
#   'Numbers': 1,
#   'price': 0.054},
#  {'token_address': '0x6f0365ca2c1dd63473f898a60f878a07e0f68a26',
#   'name': 'TopDogBeachClub',
#   'symbol': 'TDBC',
#   'Numbers': 1,
#   'price': 0.05},
#  {'token_address': '0xd0b53410454370a482979c0adaf3667c6308a801',
#   'name': 'Elite Ape Entry Coins',
#   'symbol': 'COINS',
#   'Numbers': 1,
#   'price': 0.05},
#  {'token_address': '0x2963ba471e265e5f51cafafca78310fe87f8e6d1',
#   'name': 'MakersPlace',
#   'symbol': 'MAKERS',
#   'Numbers': 2,
#   'price': 0.023},
#  {'token_address': '0x4eca3d3d8148a181226861bb3ec3514706360362',
#   'name': 'dGenesis dGen Automatons',
#   'symbol': 'DGNA',
#   'Numbers': 4,
#   'price': 0.011},
#  {'token_address': '0x0540cd12951c6dc3b06bae466914b46dcaa28cf8',
#   'name': 'Gutter Punks Flyer - Meebits',
#   'symbol': 'GPFM',
#   'Numbers': 6,
#   'price': 0.007},
#  {'token_address': '0x8eaaabe11896bd09fb852d3a5248004ec44bc793',
#   'name': 'Refractions',
#   'symbol': 'refractions',
#   'Numbers': 4,
#   'price': 0.01},
#  {'token_address': '0x7daec605e9e2a1717326eedfd660601e2753a057',
#   'name': None,
#   'symbol': None,
#   'Numbers': 1,
#   'price': 0.04},
#  {'token_address': '0x1d3ada5856b14d9df178ea5cab137d436dc55f1d',
#   'name': 'Deathbats Club',
#   'symbol': 'DBC',
#   'Numbers': 3,
#   'price': 0.0125},
#  {'token_address': '0xd4b61ef46ad352ea6b8846180c4fdd59f36056a1',
#   'name': 'Ape Harbour Dinghies',
#   'symbol': 'AHD',
#   'Numbers': 3,
#   'price': 0.01},
#  {'token_address': '0x8f4ca9a9df620ac58152f5369650dbccd006de37',
#   'name': 'Rollbit VIP Passes',
#   'symbol': 'ROLLBITVIPPASS',
#   'Numbers': 2,
#   'price': 0.015},
#  {'token_address': '0x52607cb9c342821ea41ad265b9bb6a23bea49468',
#   'name': 'Flowtys',
#   'symbol': 'FLOWTY',
#   'Numbers': 1,
#   'price': 0.03},
#  {'token_address': '0xca98fdf936243edc3bbd65dc1dcc386ec7a7d540',
#   'name': 'BAYC X OTHERSIDE LAND',
#   'symbol': 'BYOL',
#   'Numbers': 1,
#   'price': 0.03},
#  {'token_address': '0x0c6218d95735d3e12ae7c4703106e4b8e0b61010',
#   'name': 'Purrnelopes Kittens',
#   'symbol': 'PK',
#   'Numbers': 1,
#   'price': 0.022},
#  {'token_address': '0x0e1f990d264a9818460dde1b81c0b04d8a88e751',
#   'name': 'TIMEPieces x Robotos',
#   'symbol': None,
#   'Numbers': 1,
#   'price': 0.018},
#  {'token_address': '0x9523b6429924e4fac50568572cf1d24697190c1d',
#   'name': 'Magnum',
#   'symbol': 'MAGNUM',
#   'Numbers': 1,
#   'price': 0.0149},
#  {'token_address': '0x240eb6b465f61dfc965053791f963cd0f0e4fdb0',
#   'name': 'FuckinTrolls',
#   'symbol': 'FKNTRLLS',
#   'Numbers': 3,
#   'price': 0.0049},
#  {'token_address': '0x4f9835dbb442b263bbd20ff2731162101d9c3a89',
#   'name': 'Toad Punks',
#   'symbol': 'tdpnks',
#   'Numbers': 1,
#   'price': 0.014},
#  {'token_address': '0x98b486f4fd2a1526eb6fd09f200735d4a9fcadfa',
#   'name': 'Doodles Flipped',
#   'symbol': 'DOODLESFLIPPED',
#   'Numbers': 6,
#   'price': 0.002},
#  {'token_address': '0x7d256d82b32d8003d1ca1a1526ed211e6e0da9e2',
#   'name': 'Yat NFT',
#   'symbol': 'Yats',
#   'Numbers': 1,
#   'price': 0.01},
#  {'token_address': '0x343f999eaacdfa1f201fb8e43ebb35c99d9ae0c1',
#   'name': 'Loneley Aliens Space Club',
#   'symbol': 'LASC',
#   'Numbers': 1,
#   'price': 0.01},
#  {'token_address': '0xd1146680ae5a4d71f68accb6610030ced7e7afe1',
#   'name': 'MUTANT PUNKS CITY',
#   'symbol': 'MPC',
#   'Numbers': 1,
#   'price': 0.01},
#  {'token_address': '0x5537d90a4a2dc9d9b37bab49b490cf67d4c54e91',
#   'name': 'OneDayPunk',
#   'symbol': 'ODP',
#   'Numbers': 1,
#   'price': 0.009},
#  {'token_address': '0xbbfb6e466f376e493da35b5665dbfc19f7204231',
#   'name': 'GEN.ART Collection',
#   'symbol': 'GENART',
#   'Numbers': 1,
#   'price': 0.0074},
#  {'token_address': '0x60f80121c31a0d46b5279700f9df786054aa5ee5',
#   'name': 'Rarible',
#   'symbol': 'RARI',
#   'Numbers': 1,
#   'price': 0.005},
#  {'token_address': '0x7deb7bce4d360ebe68278dee6054b882aa62d19c',
#   'name': 'Planets',
#   'symbol': 'PLANET',
#   'Numbers': 4,
#   'price': 0.001},
#  {'token_address': '0xd1e5b0ff1287aa9f9a268759062e4ab08b9dacbe',
#   'name': '.crypto',
#   'symbol': 'UD',
#   'Numbers': 1,
#   'price': 0.004},
#  {'token_address': '0xa7d8d9ef8d8ce8992df33d8b8cf4aebabd5bd270',
#   'name': 'Art Blocks',
#   'symbol': 'BLOCKS',
#   'Numbers': 23,
#   'price': 0.0001},
#  {'token_address': '0x0cfb5d82be2b949e8fa73a656df91821e2ad99fd',
#   'name': '10KTF',
#   'symbol': '10KTF',
#   'Numbers': 1,
#   'price': 0.001},
#  {'token_address': '0xd8b7cc75e22031a72d7b8393113ef2536e17bde6',
#   'name': 'GEN.ART Drop',
#   'symbol': 'GENART',
#   'Numbers': 7,
#   'price': 0.0001},
#  {'token_address': '0xda7d42b6167f1497346d7b2336a6d7a603026db1',
#   'name': None,
#   'symbol': None,
#   'Numbers': 6,
#   'price': 0.0001},
#  {'token_address': '0xb66a603f4cfe17e3d27b87a8bfcad319856518b8',
#   'name': 'Rarible',
#   'symbol': 'RARI',
#   'Numbers': 2,
#   'price': 0.00025},
#  {'token_address': '0x3b3ee1931dc30c1957379fac9aba94d1c48a5405',
#   'name': 'FND NFT',
#   'symbol': 'FNDNFT',
#   'Numbers': 40,
#   'price': 1e-05},
#  {'token_address': '0xd07e72b00431af84ad438ca995fd9a7f0207542d',
#   'name': 'Hashes',
#   'symbol': 'HASH',
#   'Numbers': 3,
#   'price': 0.0001},
#  {'token_address': '0x7858fe713449bdba2dc9641ecf9defa6b8c0f62a',
#   'name': 'SpaceCowboys',
#   'symbol': 'SC',
#   'Numbers': 2,
#   'price': 0.0001},
#  {'token_address': '0x1ca39c7f0f65b4da24b094a9afac7acf626b7f38',
#   'name': 'GEN.ART',
#   'symbol': 'GA',
#   'Numbers': 1,
#   'price': 1e-05},
#  {'token_address': '0x9759226b2f8ddeff81583e244ef3bd13aaa7e4a1',
#   'name': 'Purrnelopes Country Club',
#   'symbol': 'PCC',
#   'Numbers': 1,
#   'price': 1e-06},
#  {'token_address': '0xb47e3cd837ddf8e4c57f05d70ab865de6e193bbb',
#   'name': 'CRYPTOPUNKS',
#   'symbol': 'Ͼ',
#   'Numbers': 68,
#   'price': 0},
#  {'token_address': '0x4b3406a41399c7fd2ba65cbc93697ad9e7ea61e5',
#   'name': 'Lost Poets',
#   'symbol': 'POETS',
#   'Numbers': 64,
#   'price': 0.0},
#  {'token_address': '0x495f947276749ce646f68ac8c248420045cb7b5e',
#   'name': 'OpenSea Shared Storefront',
#   'symbol': 'OPENSTORE',
#   'Numbers': 63,
#   'price': 0.0},
#  {'token_address': '0xaf90d15098275db315979b00f8a308c8c0bb980f',
#   'name': 'Gutter Punks Flyer - CryptoPunks',
#   'symbol': 'GPFCP',
#   'Numbers': 54,
#   'price': 0},
#  {'token_address': '0x60e4d786628fea6478f785a6d7e704777c86a7c6',
#   'name': 'MutantApeYachtClub',
#   'symbol': 'MAYC',
#   'Numbers': 54,
#   'price': 0.0},
#  {'token_address': '0x06b69c1c617a973e0ab91dc66442e97b490aa965',
#   'name': '',
#   'symbol': '',
#   'Numbers': 25,
#   'price': 0},
#  {'token_address': '0x75448243a3ccde04368d2c19a01a710602e5f658',
#   'name': 'BittyBots',
#   'symbol': 'BITTY',
#   'Numbers': 20,
#   'price': 0},
#  {'token_address': '0xa4d5fb4ff0fa1565fb7d8f5db88e4c0f2f445046',
#   'name': 'Notorious Frogs',
#   'symbol': 'FROGS',
#   'Numbers': 20,
#   'price': 0.0},
#  {'token_address': '0x57f1887a8bf19b14fc0df6fd9b2acc9af147ea85',
#   'name': 'Ethereum Name Service',
#   'symbol': 'ENS',
#   'Numbers': 19,
#   'price': 0.0},
#  {'token_address': '0x76be3b62873462d2142405439777e971754e8e77',
#   'name': 'parallel',
#   'symbol': 'LL',
#   'Numbers': 18,
#   'price': 0.0},
#  {'token_address': '0xfee27fb71ae3feeef2c11f8e02037c42945e87c4',
#   'name': 'Colorverse',
#   'symbol': 'RGB',
#   'Numbers': 17,
#   'price': 0},
#  {'token_address': '0x473fbdf1a797589df54751816623eb037c71ce27',
#   'name': 'Gutter Punks Comic - Flyer',
#   'symbol': 'GPCMAYC',
#   'Numbers': 16,
#   'price': 0},
#  {'token_address': '0x046427fa6b924739cd98ee507cb0db34c7a66c2e',
#   'name': 'Unidentified contract - V7hByRdrhA',
#   'symbol': '',
#   'Numbers': 10,
#   'price': 0},
#  {'token_address': '0x82c7a8f707110f5fbb16184a5933e9f78a34c6ab',
#   'name': 'Emblem Vault V4',
#   'symbol': 'Emblem.pro',
#   'Numbers': 9,
#   'price': 0.0},
#  {'token_address': '0xd07dc4262bcdbf85190c01c996b4c06a461d2430',
#   'name': 'Rarible',
#   'symbol': 'RARI',
#   'Numbers': 8,
#   'price': 0.0},
#  {'token_address': '0x99c2546aebc070fb1f286a346ec4d25e70533474',
#   'name': 'Quadrums',
#   'symbol': 'QDRMS',
#   'Numbers': 7,
#   'price': 0},
#  {'token_address': '0xeff8450c6a69217bf98f95143a8c76166b25164d',
#   'name': 'RosenBigDrop',
#   'symbol': 'Rosen',
#   'Numbers': 6,
#   'price': 0},
#  {'token_address': '0x65498bf901a0c47ba9507c8a778d2bdee4db12b4',
#   'name': 'Gutter Punks - WoWG',
#   'symbol': 'GPWOWG',
#   'Numbers': 5,
#   'price': 0},
#  {'token_address': '0x85ff6ec2bd7446c90f24f6a5e5acdd82bcd2d4be',
#   'name': 'Gutter Punks - WoW',
#   'symbol': 'GPWOW',
#   'Numbers': 5,
#   'price': 0},
#  {'token_address': '0x166a0ce5814b5188e9aa96da3dc05a38018fc927',
#   'name': 'The Shark Mob GA',
#   'symbol': 'TSMGA',
#   'Numbers': 5,
#   'price': 0},
#  {'token_address': '0x1f64347b6165ffc9a353ddc97c792401f6d7b121',
#   'name': 'ONE OF ONE',
#   'symbol': 'UNIQUE',
#   'Numbers': 4,
#   'price': 0},
#  {'token_address': '0xc4c6d110226598cd24be9efcd0e094368dd4ed8c',
#   'name': "Troll Fuckin' Tunes",
#   'symbol': 'TUNES',
#   'Numbers': 3,
#   'price': 0},
#  {'token_address': '0x3bb82ae28ba8d1744e749b54536f7b6e5f56f138',
#   'name': 'MorsEst',
#   'symbol': 'MESP',
#   'Numbers': 3,
#   'price': 0},
#  {'token_address': '0xf8a7d7f7871100d0094f1bfa723de1087e7617c3',
#   'name': 'Sounds of The Blockchain',
#   'symbol': 'SoTB',
#   'Numbers': 3,
#   'price': 0},
#  {'token_address': '0x325b07bb7392bdc365e8362dc9546265047bcd4e',
#   'name': 'Sonya_illustration',
#   'symbol': 'SONYAART',
#   'Numbers': 3,
#   'price': 0},
#  {'token_address': '0x4f8730e0b32b04beaa5757e5aea3aef970e5b613',
#   'name': 'Bloot',
#   'symbol': 'BLOOT',
#   'Numbers': 3,
#   'price': 0.0},
#  {'token_address': '0x1adfe6a7b85e89810e8d10fa60f4637c801d85c3',
#   'name': 'Voyage',
#   'symbol': 'VOYAGE',
#   'Numbers': 3,
#   'price': 0},
#  {'token_address': '0x79fc737f06c72ca9576822699e8c762d6dd0f768',
#   'name': 'Wanderer',
#   'symbol': 'WANDERER',
#   'Numbers': 3,
#   'price': 0},
#  {'token_address': '0x7ef232e01c45377b0321ff11ca50c59c5b69212b',
#   'name': 'Creep Kids Genesis',
#   'symbol': 'CRK',
#   'Numbers': 2,
#   'price': 0},
#  {'token_address': '0x11e1638d68d4eff1e60dde34710598882ac957c3',
#   'name': 'Holly+ DAO Genesis Token',
#   'symbol': 'HOLLYPLUSDAO',
#   'Numbers': 2,
#   'price': 0},
#  {'token_address': '0x1181eb587073f73b0fe4209d7041015b1d56d59c',
#   'name': 'Colorverse NFWe',
#   'symbol': 'NFWe',
#   'Numbers': 2,
#   'price': 0},
#  {'token_address': '0xd754937672300ae6708a51229112de4017810934',
#   'name': 'Deafbeef',
#   'symbol': 'DEAFBEEF',
#   'Numbers': 2,
#   'price': 0},
#  {'token_address': '0xa98771a46dcb34b34cdad5355718f8a97c8e603e',
#   'name': 'EulerBeats: Enigma',
#   'symbol': 'eBEATS',
#   'Numbers': 2,
#   'price': 0},
#  {'token_address': '0x15f5ee2362f686617ee97c166f8e1b681dda7e8c',
#   'name': 'MemeCalf-NFT',
#   'symbol': 'MemeCalf',
#   'Numbers': 2,
#   'price': 0},
#  {'token_address': '0xede64feff210f406bff709e2f375611641c2a945',
#   'name': 'cLoot.org',
#   'symbol': 'CLOOT',
#   'Numbers': 2,
#   'price': 0},
#  {'token_address': '0xa8ea63d5bfd1a133fc6149a77d0fe29943a02d5e',
#   'name': 'Melancholy',
#   'symbol': 'MLNCHL',
#   'Numbers': 2,
#   'price': 0},
#  {'token_address': '0x682ffe8a00461b727d6772e9faa8cfe6d341de09',
#   'name': 'A pulse in stillness',
#   'symbol': 'PULSE',
#   'Numbers': 2,
#   'price': 0},
#  {'token_address': '0x6bab7e940d7f3032d2ae24b9bc7c6ed0eae31292',
#   'name': 'Portraits ',
#   'symbol': 'YELLOW',
#   'Numbers': 2,
#   'price': 0},
#  {'token_address': '0xf152e743a6773fc65d3ec1a4e10db5da7d249d29',
#   'name': 'Luxeto Punk Sneaker',
#   'symbol': 'LPSD',
#   'Numbers': 2,
#   'price': 0},
#  {'token_address': '0x1dfe7ca09e99d10835bf73044a23b73fc20623df',
#   'name': 'More Loot',
#   'symbol': 'MLOOT',
#   'Numbers': 2,
#   'price': 0.0},
#  {'token_address': '0xca7ca7bcc765f77339be2d648ba53ce9c8a262bd',
#   'name': 'Tubby Cats',
#   'symbol': 'TUBBY',
#   'Numbers': 2,
#   'price': 0.0},
#  {'token_address': '0xb55b7e00152d2ef27357944a96f29271f8073f11',
#   'name': 'CryptoCatPunks by Studio Moduler',
#   'symbol': 'CCP',
#   'Numbers': 1,
#   'price': 0},
#  {'token_address': '0x33b39ad6bea0c5fd084dae8066bc3165678c4328',
#   'name': 'UNTAMED SOULS',
#   'symbol': 'US',
#   'Numbers': 1,
#   'price': 0},
#  {'token_address': '0x50842cd03177aee608840a659768c55a5405ac46',
#   'name': 'Cyber Wolves',
#   'symbol': 'CW',
#   'Numbers': 1,
#   'price': 0},
#  {'token_address': '0x462faa2995b80fbc8a3b39d24b0a9929e95a1d1f',
#   'name': 'CrazyCyberBunny',
#   'symbol': 'CCB',
#   'Numbers': 1,
#   'price': 0},
#  {'token_address': '0x0e7fb4c55d63901fb855da2d8c6a1d6941c4a77f',
#   'name': None,
#   'symbol': None,
#   'Numbers': 1,
#   'price': 0},
#  {'token_address': '0xb305904aab1d1041b9c237e46a68fc9a22d60bc2',
#   'name': '',
#   'symbol': '',
#   'Numbers': 1,
#   'price': 0},
#  {'token_address': '0xc58d5ec9b31516321cad1d0cfd4020545843606a',
#   'name': 'EulerBeats Wearables',
#   'symbol': '',
#   'Numbers': 1,
#   'price': 0},
#  {'token_address': '0x247e5c7b8279fd8fa94ab7fd48957c5bbf9762eb',
#   'name': 'WHOLENESS by SMECCEA',
#   'symbol': 'WHOLENESSBYSMECCEA',
#   'Numbers': 1,
#   'price': 0},
#  {'token_address': '0xc86ca2bb9c9c9c9f140d832de00bfa9e153fa1e3',
#   'name': 'Cyber Curated',
#   'symbol': '',
#   'Numbers': 1,
#   'price': 0},
#  {'token_address': '0x5b8773b544ec3b7d0215ec34861f1d8eaec60949',
#   'name': 'Eulerbeat Dreams Coverart & Mp3',
#   'symbol': 'EBDC',
#   'Numbers': 1,
#   'price': 0},
#  {'token_address': '0xd46939da978d70f8564fccd1965df257aa8fd726',
#   'name': 'LP07 Album Cover Art',
#   'symbol': 'LP07',
#   'Numbers': 1,
#   'price': 0},
#  {'token_address': '0x50f5474724e0ee42d9a4e711ccfb275809fd6d4a',
#   'name': "Sandbox's LANDs",
#   'symbol': 'LAND',
#   'Numbers': 1,
#   'price': 0},
#  {'token_address': '0xa2689f62d0e362607d5fad4e1798e0c2bcaef07c',
#   'name': 'Gutter Punks Flyer - Cool Cats',
#   'symbol': 'GPFCC',
#   'Numbers': 1,
#   'price': 0},
#  {'token_address': '0xd4f3a00b470c9ed76510cc92fd07e59e0a5c34d1',
#   'name': 'Gutter Punks',
#   'symbol': 'GPFCT',
#   'Numbers': 1,
#   'price': 0},
#  {'token_address': '0x80656ae3214d203d6dede78e1c5846857da64d6e',
#   'name': 'Proof of Rock',
#   'symbol': 'POR',
#   'Numbers': 1,
#   'price': 0},
#  {'token_address': '0xc29f508c87424dfdff6c618d705ddb18c5228149',
#   'name': 'PURPLE SONDER',
#   'symbol': 'AELRIC',
#   'Numbers': 1,
#   'price': 0},
#  {'token_address': '0xc485cba784d6065bbd4d2ac7e4b176f500b10c01',
#   'name': 'painful bliss.',
#   'symbol': 'PAIN',
#   'Numbers': 1,
#   'price': 0},
#  {'token_address': '0x3fc2620216c442a1566856707ebe9cdf99f21a7c',
#   'name': 'The 0010 Works',
#   'symbol': '0010',
#   'Numbers': 1,
#   'price': 0},
#  {'token_address': '0xa14938e1c098dac404608dfe741a50b79a23911c',
#   'name': None,
#   'symbol': None,
#   'Numbers': 1,
#   'price': 0},
#  {'token_address': '0x8086798d76b63ab999b852a1e75c6c38822a764f',
#   'name': 'LONELINESS AS A WAY OF LIFE',
#   'symbol': 'LNLNSS',
#   'Numbers': 1,
#   'price': 0},
#  {'token_address': '0xe51e627fbd4a81d42d5e43c926388c34060b91b1',
#   'name': 'Anatomy of Nature fig.3',
#   'symbol': 'SPLIT',
#   'Numbers': 1,
#   'price': 0},
#  {'token_address': '0x1c60df38ce83e7500efbe270285a944c6d03cca5',
#   'name': 'Inception',
#   'symbol': 'ART',
#   'Numbers': 1,
#   'price': 0},
#  {'token_address': '0xd61709c390797bc752e4123febe15a15f481e2ed',
#   'name': 'The Refriedspinach Collection',
#   'symbol': 'TRC',
#   'Numbers': 1,
#   'price': 0},
#  {'token_address': '0x049e959f152b3dec3d1f5e61d3d1f3c371d5fb10',
#   'name': 'badbird',
#   'symbol': 'BDBRD',
#   'Numbers': 1,
#   'price': 0},
#  {'token_address': '0x4a5fa827f409ad245a29824fba3cbc19ee9cc186',
#   'name': 'Illustrated Portraits',
#   'symbol': 'PORTRAIT',
#   'Numbers': 1,
#   'price': 0},
#  {'token_address': '0xe1c30894a8ff005de7993a333f96e7f5c6034371',
#   'name': 'A.Mashiro',
#   'symbol': 'AMSR',
#   'Numbers': 1,
#   'price': 0},
#  {'token_address': '0xbabd0886790027aa6ad1659f6e8bb191898349be',
#   'name': 'Collaborations',
#   'symbol': 'COLLAB',
#   'Numbers': 1,
#   'price': 0},
#  {'token_address': '0xa4acbbbbf68b255b4aef4d5553fd16c13da543a1',
#   'name': 'Lost In A Place',
#   'symbol': 'LOST',
#   'Numbers': 1,
#   'price': 0},
#  {'token_address': '0x21ae76b5672431a9d145452ca0cf441bb0cdb646',
#   'name': 'Fantastical Surreal ',
#   'symbol': 'FS',
#   'Numbers': 1,
#   'price': 0},
#  {'token_address': '0x7b91d14a4688340fdaf2f0be99843bb0fa6b5b4a',
#   'name': 'ƧUЯRΞΛL ЯΞΛLITY',
#   'symbol': 'SR',
#   'Numbers': 1,
#   'price': 0},
#  {'token_address': '0x81e2ca667b0dabd86b1457fab8e1d7eecf53ab47',
#   'name': 'Ink Visions',
#   'symbol': 'INK',
#   'Numbers': 1,
#   'price': 0},
#  {'token_address': '0x9d90308d16b94c38048c782bdd8104a964758a23',
#   'name': 'fees.wtf NFT',
#   'symbol': 'fees.wtf',
#   'Numbers': 1,
#   'price': 0},
#  {'token_address': '0x39cda2184e833c92badd4b7806d923ba9af53866',
#   'name': 'Big Cats TYG',
#   'symbol': 'BCT',
#   'Numbers': 1,
#   'price': 0},
#  {'token_address': '0x620de236fcce1e061725f382be3d1bf689f29a5c',
#   'name': 'Lulupunk',
#   'symbol': 'LLPK',
#   'Numbers': 1,
#   'price': 0},
#  {'token_address': '0x45843e61a956cf262a8899a24889c41a5c209662',
#   'name': 'CryptoKlaus',
#   'symbol': 'CK',
#   'Numbers': 1,
#   'price': 0}]

# %%
with open('NFT_TokenList.json', 'w') as outfile:
    outfile.write(json.dumps(NFT_result_list))

# %% [markdown]
# ## Get all ERC20 tokens in interest wallet

# %%
params = {
    'chain': 'eth',
}

# %%
interest_address = over_count["account"]
erc20_result_list = []
mapping = {}

""" Get all token of one account """
i = 0
for owner_addr in interest_address:
    url = f"https://deep-index.moralis.io/api/v2/{owner_addr}/erc20"
    response = json.loads(requests.get(url, headers=headers, params=params).text)
    
    for r in response:
        decimal = float(r["decimals"]) if r["decimals"] else 1e-18
        if r["token_address"] in mapping.keys():
            erc20_result_list[mapping[r["token_address"]]]["Numbers"] += float(r["balance"])/ 10**decimal
        else:
            mapping[r["token_address"]] = i
            i += 1
            tmp = {
                'token_address': r["token_address"],
                'name': r["name"],
                'symbol': r["symbol"],
                'Numbers': float(r["balance"])/ 10**decimal,
            }
            erc20_result_list.append(tmp)

# %%
# Sort by collection Numbers
erc20_result_list = sorted(erc20_result_list, key=lambda r: r["Numbers"], reverse=True)
erc20_result_list
# Out:
# [{'token_address': '0x4b3464fe6a37ce9cfe2956056f447261fd7ea614',
#   'name': 'Rabbit Rocket',
#   'symbol': 'Rabbit',
#   'Numbers': 44758912878009.23},
#  {'token_address': '0xa3986e46f051e275e575930107848c4eba83a788',
#   'name': 'Squid Game V2',
#   'symbol': 'Squid Game V2',
#   'Numbers': 13907497505997.0},
#  {'token_address': '0xf27adb015958b4f02128ecfa3ce59b3772e9676a',
#   'name': 'Harvard Metaverse',
#   'symbol': 'Harvard',
#   'Numbers': 2116467992977.0798},
#  {'token_address': '0xce4fd7ea4c894ed145ecb996a79c336f3a279334',
#   'name': 'Mfers Coin',
#   'symbol': 'Mfers',
#   'Numbers': 1825479101141.389},
#  {'token_address': '0xf71ba4058c7ea23992a2311add6862d854b3d229',
#   'name': 'MAYC COIN',
#   'symbol': 'MAYC',
#   'Numbers': 1708211504684.831},
#  {'token_address': '0xd3bf5b01aed2546645708ccbfc1ac0753089eaec',
#   'name': 'Nikeland Metaverse',
#   'symbol': 'Nikeland',
#   'Numbers': 1602384558800.8508},
#  {'token_address': '0x9fc499e6215f2aa51b61eae1cfffdf52418bf712',
#   'name': 'Disney Metaverse',
#   'symbol': 'DISNEY',
#   'Numbers': 1579537761076.001},
#  {'token_address': '0xe44c8ee0622647d2563a8b2732941772328a751b',
#   'name': 'Imaginary Ones',
#   'symbol': 'Imaginary Ones',
#   'Numbers': 1459220681844.6455},
#  {'token_address': '0x41e38882257d0a318c8fb5f1c4e4f50a0b85f56e',
#   'name': 'LG Metaverse',
#   'symbol': 'LG',
#   'Numbers': 1287311286941.4475},
#  {'token_address': '0x4e22eb365dcc6f34ae14f8800203dfe3fda2df4e',
#   'name': 'Invisible Friends',
#   'symbol': 'Invisible',
#   'Numbers': 1176457174280.8801},
#  {'token_address': '0x1220902299fc2807dd6fa4a0900ae34bc11bed5e',
#   'name': 'World Of Women',
#   'symbol': 'World Of Women',
#   'Numbers': 1148198586583.1704},
#  {'token_address': '0x205c58815d158b38e42b979a81a740dfb2eff15c',
#   'name': 'NASA Metaverse',
#   'symbol': 'NASA',
#   'Numbers': 1097965502695.7126},
#  {'token_address': '0xe29cca6ae51d4b815ccf084b0f7154e2092e9621',
#   'name': 'Cool Cats Coin',
#   'symbol': 'Cool Cats',
#   'Numbers': 1068353860538.7018},
#  {'token_address': '0x8e546846a9a15bbdb695599b32d5d2de37d151e4',
#   'name': 'Patek Philippe Metaverse',
#   'symbol': 'Patek Philippe',
#   'Numbers': 1052140369121.4131},
#  {'token_address': '0x288c72aab7e6d1f688964c95404bc34dc0978528',
#   'name': 'Apple metaverse',
#   'symbol': 'APPLE',
#   'Numbers': 1004936007735.3873},
#  {'token_address': '0x7841479c5976b8184dbcde9a7a5113901b233efb',
#   'name': 'STEPN Governance Token',
#   'symbol': 'GMT',
#   'Numbers': 900000000000.0},
#  {'token_address': '0xfab905850bb61af584dc5c7030479ee7a44a2f0a',
#   'name': 'CryptoPunks',
#   'symbol': 'CryptoPunks',
#   'Numbers': 889411647361.3843},
#  {'token_address': '0xe5d89696d170a5af25d38ffb96b6539a0b537653',
#   'name': 'Bikini Metaverse',
#   'symbol': 'Bikini',
#   'Numbers': 830327027861.0763},
#  {'token_address': '0xedd6b61a2e060a6f3d701b6cdac05f80cac15d5a',
#   'name': 'Nexon Metaverse',
#   'symbol': 'Nexon',
#   'Numbers': 822625181917.7892},
#  {'token_address': '0x4f22dd9cc043518446d5d0fdca82d00a5563a399',
#   'name': 'BAKC COIN',
#   'symbol': 'BAKC',
#   'Numbers': 818297349314.0883},
#  {'token_address': '0xb7de3bb824a17e309134d913f354d29a04fec457',
#   'name': 'Verizon Metaverse',
#   'symbol': 'Verizon',
#   'Numbers': 763649219850.1014},
#  {'token_address': '0x7cb05d1d1ffff52a0aa6143988a11927e599384d',
#   'name': 'Powell DAO',
#   'symbol': 'Powell',
#   'Numbers': 734901753974.8658},
#  {'token_address': '0xa227de65722742aa9269ec5d4d2a99c45b35cc5f',
#   'name': 'Punk Coin',
#   'symbol': 'Punk',
#   'Numbers': 616134464391.1177},
#  {'token_address': '0x22e845cbbafda629c0401de5f23e3f73b0cfa68a',
#   'name': 'BAYC Token',
#   'symbol': 'BAYC',
#   'Numbers': 583902944208.0671},
#  {'token_address': '0x5afc8f7374f501669a3a6693fa7e6c0df7bd819d',
#   'name': 'CLONE X',
#   'symbol': 'CLONE',
#   'Numbers': 578771364048.3153},
#  {'token_address': '0x3972e6316c23fbdb98906b627c43e335642cddf3',
#   'name': 'HelloKitty Metaverse',
#   'symbol': 'HelloKitty',
#   'Numbers': 577467734607.1366},
#  {'token_address': '0x8ee84fed29b2e7161d373976c5a13e933793ca3e',
#   'name': 'Amazon Metaverse',
#   'symbol': 'Amazon',
#   'Numbers': 525322384592.06995},
#  {'token_address': '0x7be1520709f0bce6b43e07b172db49fd7b944876',
#   'name': 'Red Bull Metaverse',
#   'symbol': 'RedBull',
#   'Numbers': 499043557467.50476},
#  {'token_address': '0x6981b63574ce3c5d3987179a417c7b66feb5d579',
#   'name': 'BombCrypto',
#   'symbol': 'B0MB3R',
#   'Numbers': 250000000000.0},
#  {'token_address': '0x7c2d36abcb16ef57fb3624f3ebf9fa584e449e86',
#   'name': 'Epic Games Metaverse',
#   'symbol': 'Epic Games',
#   'Numbers': 133034946643.31796},
#  {'token_address': '0xd49717013d7d752b457e603ef6fca7f0cddb1745',
#   'name': 'DairyQueen Metaverse',
#   'symbol': 'DairyQueen',
#   'Numbers': 99301254229.34152},
#  {'token_address': '0xf5c6e17e6cbd61b4a3d2ce321161ef4bdad2c12f',
#   'name': 'Riot Games',
#   'symbol': 'Riot',
#   'Numbers': 73540581155.059},
#  {'token_address': '0xe87e0ee01aa0e836f005e67c251a56e1c17237f2',
#   'name': 'DeBank DAO',
#   'symbol': 'DBD',
#   'Numbers': 61946145446.99648},
#  {'token_address': '0xde5b34a43929192a3dded8b9391d3a5cb4b7270e',
#   'name': 'MetaMask DAO',
#   'symbol': 'METADAO',
#   'Numbers': 39252546604.35483},
#  {'token_address': '0xcf4b20e54c094c758cb109805e2fa5c378a08afe',
#   'name': 'Shiba Inu Hodler',
#   'symbol': 'SHIBAHODLER',
#   'Numbers': 28091749526.142036},
#  {'token_address': '0xdce8b8bd8889ae97933f9bb33632bb4b2b763bb1',
#   'name': 'Ubisoft Metaverse',
#   'symbol': 'Ubisoft',
#   'Numbers': 21354113765.942543},
#  {'token_address': '0x1cf20d6bdfd76487487fbd417a46198f6d5b96b7',
#   'name': 'MetaMask DAO',
#   'symbol': 'MaskDAO',
#   'Numbers': 21028471757.579247},
#  {'token_address': '0x3b484b82567a09e2588a13d54d032153f0c0aee0',
#   'name': 'SOS',
#   'symbol': 'SOS',
#   'Numbers': 10176246571.219704},
#  {'token_address': '0xb639687c6768ab33996541d05948dd621a012503',
#   'name': 'Discord DAO',
#   'symbol': 'Discord',
#   'Numbers': 8977496578.878891},
#  {'token_address': '0x9b4109cfbf22348260db8d36780554d7fd3898ff',
#   'name': 'Subway Metaverse',
#   'symbol': 'Subway',
#   'Numbers': 6077755441.46719},
#  {'token_address': '0x596651f20ea621e2af6ed1e3cefc4511c91181ee',
#   'name': 'Gear DAO',
#   'symbol': 'GEAR',
#   'Numbers': 5843347027.903645},
#  {'token_address': '0xe50a082a2853ab88820852ce8b6bab0346050954',
#   'name': 'POAP Dao',
#   'symbol': 'POAPDAO',
#   'Numbers': 5108430276.320326},
#  {'token_address': '0x6b5b49a4dff73e9b9d7032eac608914f8cccbc8a',
#   'name': 'PHILIPS Metaverse',
#   'symbol': 'PHILIPS',
#   'Numbers': 4991893142.407146},
#  {'token_address': '0x59bd59e1473271ad037faf1fe5fb821522d7aade',
#   'name': 'Coinbase DAO',
#   'symbol': 'COINBASE',
#   'Numbers': 4559193105.827674},
#  {'token_address': '0x6a1dc48a348740b62ed7a7943d53d9c84f35b326',
#   'name': 'Skype Metaverse',
#   'symbol': 'Skype',
#   'Numbers': 3988244616.848803},
#  {'token_address': '0x46adf9e560d22c8c6ab028052f8cf0b0b97a55d2',
#   'name': 'Supercell Metaverse',
#   'symbol': 'Supercell',
#   'Numbers': 3736702692.3245883},
#  {'token_address': '0x33bd8d4b90e3632742cd0d741f95e9453ae49f92',
#   'name': 'Gameloft Metaverse',
#   'symbol': 'Gameloft',
#   'Numbers': 3477357159.0511284},
#  {'token_address': '0xe4a581c3e7038957f628027ee1249fdd5fdb2969',
#   'name': 'DreamWorks Metaverse',
#   'symbol': 'DreamWorks',
#   'Numbers': 3073970255.05153},
#  {'token_address': '0xf0a06c0612591c8de92ae4fe448426f9094ee823',
#   'name': 'AzukiCoin',
#   'symbol': 'Azuki',
#   'Numbers': 2880720210.038291},
#  {'token_address': '0xf39e77f4f46f1784cbd4fd39ebde4753870104f8',
#   'name': 'Target Metaverse',
#   'symbol': 'Target',
#   'Numbers': 2730271374.92686},
#  {'token_address': '0x07d5e4db69cb04032ed7c92109fcb5a3e8dc47fa',
#   'name': 'Pokemon Metaverse',
#   'symbol': 'Pokemon',
#   'Numbers': 1923987848.3456721},
#  {'token_address': '0x78785f09deb083ff9c1ac3cce023c903e3b0d9bf',
#   'name': 'Shiba Dao',
#   'symbol': 'SHIBADAO',
#   'Numbers': 1808538942.1618507},
#  {'token_address': '0x1884f9eda99ca66c72d6fecdfbf9689d6bbe3b03',
#   'name': 'XBOX Metaverse',
#   'symbol': 'XBOX',
#   'Numbers': 1788266029.9146285},
#  {'token_address': '0x20806e0c9b9f7b65d59a9959f029eb752196bdc5',
#   'name': 'Lentil Eater',
#   'symbol': 'LENTIL',
#   'Numbers': 1455682397.2300644},
#  {'token_address': '0xa91827215697bb20d142bf46db3d1bfd8f5264dc',
#   'name': 'Mastercard Metaverse',
#   'symbol': 'Mastercard',
#   'Numbers': 1293734913.9516604},
#  {'token_address': '0x5d7274dff3ac2549ba47024745c202b588099179',
#   'name': 'Mini FLOKI Token',
#   'symbol': 'Mini FLOKI',
#   'Numbers': 1279500000.0},
#  {'token_address': '0x9ddec70ab6ff39491c449d5ce3a02a852dc8b80a',
#   'name': 'Richard Mille Metaverse',
#   'symbol': 'Richard Mille',
#   'Numbers': 1275044549.833596},
#  {'token_address': '0x606375881d98452478b265b577840185511353f3',
#   'name': 'Walmart Metaverse',
#   'symbol': 'Walmart',
#   'Numbers': 522792983.79448485},
#  {'token_address': '0xa04e18e86408fa651c144f10de5236493d070e78',
#   'name': 'Amazon Metaverse',
#   'symbol': 'Amazon',
#   'Numbers': 522792983.79448485},
#  {'token_address': '0xd2f91aafce21131173a6efbc9801445be0b71c71',
#   'name': 'Nike Metaverse',
#   'symbol': 'Nike',
#   'Numbers': 522792983.79448485},
#  {'token_address': '0x77b7340faa3d8f75eed612d051b64a5a5f6167f3',
#   'name': 'NEW YORK COIN',
#   'symbol': 'NEW YORK',
#   'Numbers': 522792983.79448485},
#  {'token_address': '0x41a014616bbbc9ebba81cd23a884b2d300045d48',
#   'name': 'COCA COLA Metaverse',
#   'symbol': 'COCA COLA',
#   'Numbers': 522792983.79448485},
#  {'token_address': '0x978d20bc2a6767917c9f48c7a4c5e95961802453',
#   'name': 'SUPA  Foundation',
#   'symbol': 'SUPA',
#   'Numbers': 505296437.19195354},
#  {'token_address': '0xa5a711c6b34f41164fe94d997c9e3ac0c4617e8c',
#   'name': 'Big Green Dao',
#   'symbol': 'BGD',
#   'Numbers': 476345441.0022563},
#  {'token_address': '0x013bb7458f51b2e4c06eed814b8ef353dac947e9',
#   'name': 'SEGA Metaverse',
#   'symbol': 'SEGA',
#   'Numbers': 90911001.36240952},
#  {'token_address': '0xdc98c5543f3004debfaad8966ec403093d0aa4a8',
#   'name': 'Etherrock #72',
#   'symbol': 'PEBBLE',
#   'Numbers': 72000000.0},
#  {'token_address': '0xe80c0cd204d654cebe8dd64a4857cab6be8345a3',
#   'name': 'JPEG’d Governance Token',
#   'symbol': 'JPEG',
#   'Numbers': 46946708.02572082},
#  {'token_address': '0xefd6c64533602ac55ab64442307f6fe2c9307305',
#   'name': 'APE',
#   'symbol': 'APE',
#   'Numbers': 38482589.90208715},
#  {'token_address': '0x265befe2b1a0f4f646dea96ba09c1656b74bda91',
#   'name': 'abSHIBA.com',
#   'symbol': 'ABSHIBA.com',
#   'Numbers': 17648460.0},
#  {'token_address': '0x2e41d4c356cc98a49e72d8f461141fc96878aa1d',
#   'name': 'ApeX',
#   'symbol': 'APX',
#   'Numbers': 10451877.56150357},
#  {'token_address': '0x91138bdb14afa919e7204ccd1f668411c22d91f0',
#   'name': 'FUCK DAO',
#   'symbol': 'Fuck',
#   'Numbers': 2792983.794484848},
#  {'token_address': '0x7e05540a61b531793742fde0514e6c136b5fbafe',
#   'name': 'FodlStake',
#   'symbol': 'xFODL',
#   'Numbers': 2126955.6642625616},
#  {'token_address': '0xc12d1c73ee7dc3615ba4e37e4abfdbddfa38907e',
#   'name': 'KickToken',
#   'symbol': 'KICK',
#   'Numbers': 1777776.0},
#  {'token_address': '0xcb56b52316041a62b6b5d0583dce4a8ae7a3c629',
#   'name': 'Cigarette Token',
#   'symbol': 'CIG',
#   'Numbers': 1600000.0},
#  {'token_address': '0x9f14db5a794565d952f01e65600793bee20e9269',
#   'name': 'Layer 3',
#   'symbol': 'L3T',
#   'Numbers': 1350381.0262976869},
#  {'token_address': '0x5a35a6686db167b05e2eb74e1ede9fb5d9cdb3e0',
#   'name': 'Cigarette Token',
#   'symbol': 'CIG',
#   'Numbers': 1200000.0},
#  {'token_address': '0x08164ee2dda4e8aab7a42ccc13aadd2b296395ae',
#   'name': 'ApeCoin',
#   'symbol': 'APE',
#   'Numbers': 1177766.8374036117},
#  {'token_address': '0xe0736f3f455f1dbd29bf6f8346ead22f5cf78d08',
#   'name': 'Foundation',
#   'symbol': 'FND',
#   'Numbers': 1115209.2857715164},
#  {'token_address': '0x82dfdb2ec1aa6003ed4acba663403d7c2127ff67',
#   'name': 'akSwap.io',
#   'symbol': 'akSwap.io',
#   'Numbers': 1000000.0},
#  {'token_address': '0x72c07d9151dce2ea862595487ef7e21cc312e564',
#   'name': 'Zapper.Fi',
#   'symbol': 'ZAPP',
#   'Numbers': 985498.5352449248},
#  {'token_address': '0x34278f6f40079eae344cbac61a764bcf85afc949',
#   'name': 'FF9.io',
#   'symbol': 'FF9.io',
#   'Numbers': 900000.0},
#  {'token_address': '0x2ceee24f8d03fc25648c68c8e6569aa0512f6ac3',
#   'name': 'ABCHANGE.io',
#   'symbol': 'XCH',
#   'Numbers': 894393.0},
#  {'token_address': '0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48',
#   'name': 'USD Coin',
#   'symbol': 'USDC',
#   'Numbers': 884013.05118},
#  {'token_address': '0xf12ce5503e4bedb7178951321925e4306c4c3b12',
#   'name': 'SupDao.com',
#   'symbol': 'SupDao.com',
#   'Numbers': 799999.9999999999},
#  {'token_address': '0x028171bca77440897b824ca71d1c56cac55b68a3',
#   'name': 'Aave interest bearing DAI',
#   'symbol': 'aDAI',
#   'Numbers': 640668.3341002063},
#  {'token_address': '0x0ec78ed49c2d27b315d462d43b5bab94d2c79bf8',
#   'name': 'ZERO',
#   'symbol': 'ZERO',
#   'Numbers': 612480.7822037557},
#  {'token_address': '0xc85e0474068dba5b49450c26879541ee6cc94554',
#   'name': 'KyDy.org',
#   'symbol': 'KyDy.org',
#   'Numbers': 600000.0},
#  {'token_address': '0xb699dab9b3f981a01abc0474f085427d20d0d602',
#   'name': 'YeSwap.net',
#   'symbol': 'YeSwap.net',
#   'Numbers': 600000.0},
#  {'token_address': '0x3495ffcee09012ab7d827abf3e3b3ae428a38443',
#   'name': 'BeautyChain',
#   'symbol': 'BEC',
#   'Numbers': 571260.42},
#  {'token_address': '0xb1a2efe104e253cb36a7b26eeaf9c20cc2c56130',
#   'name': 'Lens Protocol',
#   'symbol': 'LENS',
#   'Numbers': 570380.9181073976},
#  {'token_address': '0xf9d25eb4c75ed744596392cf89074afaa43614a8',
#   'name': 'Up1.org',
#   'symbol': 'Up1.org',
#   'Numbers': 565270.0},
#  {'token_address': '0x1412eca9dc7daef60451e3155bb8dbf9da349933',
#   'name': 'A68.net',
#   'symbol': 'A68.net',
#   'Numbers': 563935.68},
#  {'token_address': '0xc5d105e63711398af9bbff092d4b6769c82f793d',
#   'name': 'BeautyChain',
#   'symbol': 'BEC',
#   'Numbers': 502950.5},
#  {'token_address': '0x4af9ab04615cb91e2ee8cbedb43fb52ed205041b',
#   'name': 'KHEX.net',
#   'symbol': 'KHEX.net',
#   'Numbers': 484642.0},
#  {'token_address': '0x14026711b9b89f699916f608fa997944e3269f20',
#   'name': 'Monkeyverse',
#   'symbol': 'MONKE',
#   'Numbers': 331362.2029020689},
#  {'token_address': '0xd667a84005975eef906e980f200541974a8c9766',
#   'name': 'WxFi.io',
#   'symbol': 'WxFi.io',
#   'Numbers': 300000.0},
#  {'token_address': '0xffa55849a7309c7f4fb4de88d804fd546a66c271',
#   'name': 'DyDex.io',
#   'symbol': 'DyDex.io',
#   'Numbers': 300000.0},
#  {'token_address': '0x01454cdc3fab2a026cc7d1cb2aea9b909d5ba0ee',
#   'name': 'deApy.org',
#   'symbol': 'deApy.org',
#   'Numbers': 300000.0},
#  {'token_address': '0xe1b3f4849c8959f53edd3ab932e0f145daf865c1',
#   'name': 'Key7.net',
#   'symbol': 'Key7.net',
#   'Numbers': 294402.0},
#  {'token_address': '0xd9c082b563cbddc7698d0843ccb320486e724148',
#   'name': 'Terraswap',
#   'symbol': 'TSP',
#   'Numbers': 240481.4249665821},
#  {'token_address': '0x657c9bd6dd653ba3de3eb95b88ddfdeea1f4ea76',
#   'name': 'Bored Ape DAO',
#   'symbol': 'Ape DAO',
#   'Numbers': 200000.0},
#  {'token_address': '0x4d224452801aced8b2f0aebe155379bb5d594381',
#   'name': 'ApeCoin',
#   'symbol': 'APE',
#   'Numbers': 196457.87678914264},
#  {'token_address': '0xbcca60bb61934080951369a648fb03df4f96263c',
#   'name': 'Aave interest bearing USDC',
#   'symbol': 'aUSDC',
#   'Numbers': 164623.999074},
#  {'token_address': '0x2a3bff78b79a009976eea096a51a948a3dc00e34',
#   'name': 'Wilder',
#   'symbol': 'WILD',
#   'Numbers': 154967.06817972657},
#  {'token_address': '0xba5bde662c17e2adff1075610382b9b691296350',
#   'name': 'SuperRare',
#   'symbol': 'RARE',
#   'Numbers': 101271.29007954283},
#  {'token_address': '0xe54a0e24d604af7489eaf4c12a85a89fa0bb0cc7',
#   'name': 'Doodles',
#   'symbol': 'DOODLE',
#   'Numbers': 99999.99999999999},
#  {'token_address': '0xfa327eb9111a5283167734efb637db46c990a27b',
#   'name': 'Euler Pool: Ribbon',
#   'symbol': 'eRBN',
#   'Numbers': 97624.64861708214},
#  {'token_address': '0xa2cd3d43c775978a96bdbf12d733d5a1ed94fb18',
#   'name': 'Chain',
#   'symbol': 'XCN',
#   'Numbers': 55737.70491803},
#  {'token_address': '0x3432b6a60d23ca0dfca7761b7ab56459d9c964d0',
#   'name': 'Frax Share',
#   'symbol': 'FXS',
#   'Numbers': 48814.41327088753},
#  {'token_address': '0xfebc1195e47043e0d2c5791d7cd9519bb631e5c9',
#   'name': '8DAO TOKEN',
#   'symbol': '8DAO',
#   'Numbers': 40000.0},
#  {'token_address': '0xb594f65151ff240e378c611dd68112df67bd420d',
#   'name': '8DAO TOKEN',
#   'symbol': '8DAO',
#   'Numbers': 40000.0},
#  {'token_address': '0x808507121b80c02388fad14726482e061b8da827',
#   'name': 'Pendle',
#   'symbol': 'PENDLE',
#   'Numbers': 39946.41723771381},
#  {'token_address': '0xc92e74b131d7b1d46e60e07f3fae5d8877dd03f0',
#   'name': 'Minereum',
#   'symbol': 'MNE',
#   'Numbers': 32000.0},
#  {'token_address': '0x426ca1ea2406c07d75db9585f22781c096e3d0e0',
#   'name': 'Minereum',
#   'symbol': 'MNE',
#   'Numbers': 32000.0},
#  {'token_address': '0x0000000000095413afc295d19edeb1ad7b71c952',
#   'name': 'Tokenlon',
#   'symbol': 'LON',
#   'Numbers': 22800.0},
#  {'token_address': '0xc1f5ba8bab3ca299f9817876a6715627f9e2b11a',
#   'name': 'FIFA.win',
#   'symbol': 'FIFAmini',
#   'Numbers': 20180.614},
#  {'token_address': '0xcda7390c64c825c3c420ddd5721bc93bd156c08c',
#   'name': 'MAYCdao.io',
#   'symbol': 'MAYCdao.io',
#   'Numbers': 16665.0},
#  {'token_address': '0x6b3595068778dd592e39a122f4f5a5cf09c90fe2',
#   'name': 'SushiToken',
#   'symbol': 'SUSHI',
#   'Numbers': 16039.983214239339},
#  {'token_address': '0xdfe7d03eac9a84e1a959d1a9245aa78baea8fd8b',
#   'name': 'BAKCdao.io',
#   'symbol': 'BAKCdao.io',
#   'Numbers': 11110.0},
#  {'token_address': '0xcc3d334b20a37bf3ed79b1ab6a72efda23323822',
#   'name': 'cloneXdao.io',
#   'symbol': 'cloneXdao.io',
#   'Numbers': 11110.0},
#  {'token_address': '0x0391d2021f89dc339f60fff84546ea23e337750f',
#   'name': 'BarnBridge Governance Token',
#   'symbol': 'BOND',
#   'Numbers': 10000.0},
#  {'token_address': '0x382f2991a93462905a8b8b65adfcec37b99db711',
#   'name': 'BEANZ Official',
#   'symbol': 'BEANZ',
#   'Numbers': 10000.0},
#  {'token_address': '0x2f141ce366a2462f02cea3d12cf93e4dca49e4fd',
#   'name': 'Free Coin',
#   'symbol': 'FREE',
#   'Numbers': 10000.0},
#  {'token_address': '0x8798249c2e607446efb7ad49ec89dd1865ff4272',
#   'name': 'SushiBar',
#   'symbol': 'xSUSHI',
#   'Numbers': 8582.793879503026},
#  {'token_address': '0x4ab16cdc82a4ea4727ab40caee1bb46622c13641',
#   'name': 'Sablier: Governance Token',
#   'symbol': 'SABLIER',
#   'Numbers': 6663.292618365543},
#  {'token_address': '0xbd8240c23ec98b21f38c5d3e1eea957ab80da9ca',
#   'name': 'BAYCcoin.io',
#   'symbol': 'APECOIN',
#   'Numbers': 5555.0},
#  {'token_address': '0x9a271913906594a2dac3b7b4bd2ae0a99c3657bc',
#   'name': 'CoolCatsDAO.io',
#   'symbol': 'CoolCatsDAO.io',
#   'Numbers': 5555.0},
#  {'token_address': '0x4b05e6e8cb88b69a971ffe8af2a7d7a21edf3afb',
#   'name': 'MurakamiDAO.io',
#   'symbol': 'MurakamiDAO.io',
#   'Numbers': 5555.0},
#  {'token_address': '0x329d75f6d8a95b23b021665db5d63e93e0f1079a',
#   'name': 'OpenSea',
#   'symbol': 'OPEN',
#   'Numbers': 4352.9157743177875},
#  {'token_address': '0xba5f00a28f732f23ba946c594716496ebdc9aef5',
#   'name': 'BKEX.COM Token',
#   'symbol': 'bkex.com',
#   'Numbers': 2018.0611000000001},
#  {'token_address': '0xd3ace836e47f7cf4948dffd8ca2937494c52580c',
#   'name': 'Free BOB Tokens - BobsRepair.com',
#   'symbol': 'BOBx',
#   'Numbers': 1500.0},
#  {'token_address': '0x12e56851ec22874520dc4c7fa0a8a8d7dba1bac8',
#   'name': 'GEN.ART',
#   'symbol': 'GENART',
#   'Numbers': 1491.0},
#  {'token_address': '0x7e9e431a0b8c4d532c745b1043c7fa29a48d4fba',
#   'name': 'eosDAC Community Owned EOS Block Producer ERC20 Tokens',
#   'symbol': 'eosDAC',
#   'Numbers': 1199.0},
#  {'token_address': '0xd4ae0807740df6fbaa7a258907132a2ac8d52fbc',
#   'name': 'KEOSToken',
#   'symbol': 'KEOS',
#   'Numbers': 1199.0},
#  {'token_address': '0x667fd83e24ca1d935d36717d305d54fa0cac991c',
#   'name': 'Collector Coin',
#   'symbol': 'AGS',
#   'Numbers': 1000.0},
#  {'token_address': '0x416935c684686877e3931fe8d766cafc5b398ebf',
#   'name': 'Cryptonex (CNX)',
#   'symbol': 'CNX',
#   'Numbers': 1000.0},
#  {'token_address': '0x7b2f9706cd8473b4f5b7758b0171a9933fc6c4d6',
#   'name': 'An Etheal Promo',
#   'symbol': 'HEALP',
#   'Numbers': 911.0},
#  {'token_address': '0x64d91f12ece7362f91a6f8e7940cd55f05060b92',
#   'name': 'Burn',
#   'symbol': 'ASH',
#   'Numbers': 795.5012349210117},
#  {'token_address': '0xee3b9b531f4c564c70e14b7b3bb7d516f33513ff',
#   'name': 'DeFi Omega',
#   'symbol': 'DFIO',
#   'Numbers': 500.0},
#  {'token_address': '0x1bbb57def2f6192f0b9b8565f49034bf1fcdb604',
#   'name': 'StackToken',
#   'symbol': 'STACK',
#   'Numbers': 414.0},
#  {'token_address': '0xc18360217d8f7ab5e7c516566761ea12ce7f9d72',
#   'name': 'Ethereum Name Service',
#   'symbol': 'ENS',
#   'Numbers': 387.98550488042326},
#  {'token_address': '0xd4de05944572d142fbf70f3f010891a35ac15188',
#   'name': 'Bulleon Promo Token',
#   'symbol': 'BULLEON PROMO',
#   'Numbers': 365.0},
#  {'token_address': '0xdac17f958d2ee523a2206206994597c13d831ec7',
#   'name': 'Tether USD',
#   'symbol': 'USDT',
#   'Numbers': 288.000005},
#  {'token_address': '0xf4d2888d29d722226fafa5d9b24f9164c092421e',
#   'name': 'LooksRare Token',
#   'symbol': 'LOOKS',
#   'Numbers': 200.0},
#  {'token_address': '0xf6276830c265a779a2225b9d2fcbab790cbeb92b',
#   'name': 'XCELTOKEN',
#   'symbol': 'XCEL',
#   'Numbers': 200.0},
#  {'token_address': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2',
#   'name': 'Wrapped Ether',
#   'symbol': 'WETH',
#   'Numbers': 145.92100152811994},
#  {'token_address': '0x5eb87caa0105a63aa87a36c7bd2573bd13e84fae',
#   'name': 'BQT',
#   'symbol': 'BQT',
#   'Numbers': 143.2439},
#  {'token_address': '0x07a5efd3c3a5c540b8ae5d8604d1487e5bac4c8e',
#   'name': 'HoweyCoin',
#   'symbol': 'HOW',
#   'Numbers': 100.0},
#  {'token_address': '0x8c4e7f814d40f8929f9112c5d09016f923d34472',
#   'name': 'XCELTOKEN PLUS',
#   'symbol': 'XLAB',
#   'Numbers': 100.0},
#  {'token_address': '0xf509cdcdf44a0bcd2953ce3f03f4b433ef6e4c44',
#   'name': 'Fomoverse Token',
#   'symbol': 'FOMO',
#   'Numbers': 69.0},
#  {'token_address': '0xb47e3cd837ddf8e4c57f05d70ab865de6e193bbb',
#   'name': 'CRYPTOPUNKS',
#   'symbol': 'Ͼ',
#   'Numbers': 68.0},
#  {'token_address': '0xf230b790e05390fc8295f4d3f60332c93bed42e2',
#   'name': 'Tronix',
#   'symbol': 'TRX',
#   'Numbers': 61.0},
#  {'token_address': '0xbab6f30c81209433a3ced28ca8e19256440547d9',
#   'name': 'Yu Gi Oh',
#   'symbol': 'YGO',
#   'Numbers': 50.0},
#  {'token_address': '0x076641af1b8f06b7f8c92587156143c109002cbe',
#   'name': 'SoPay',
#   'symbol': 'SOP',
#   'Numbers': 16.0},
#  {'token_address': '0x2f85e502a988af76f7ee6d83b7db8d6c0a823bf9',
#   'name': 'LatiumX',
#   'symbol': 'LATX',
#   'Numbers': 10.0},
#  {'token_address': '0xbddab785b306bcd9fb056da189615cc8ece1d823',
#   'name': 'Ebakus',
#   'symbol': 'EBK',
#   'Numbers': 8.746002661},
#  {'token_address': '0xf3e014fe81267870624132ef3a646b8e83853a96',
#   'name': 'VIN',
#   'symbol': 'VIN',
#   'Numbers': 7.77},
#  {'token_address': '0x2a46f2ffd99e19a89476e2f62270e0a35bbf0756',
#   'name': None,
#   'symbol': None,
#   'Numbers': 7.0},
#  {'token_address': '0x1d16bf5cf1bbffa15983af4b034a795331fe2580',
#   'name': 'House of Medici',
#   'symbol': 'HOM',
#   'Numbers': 6.7},
#  {'token_address': '0xcbdeb4ff6cb834a83bf438d26a2fb5e6f53319b7',
#   'name': 'PunkETH.io',
#   'symbol': 'NFT',
#   'Numbers': 6.0},
#  {'token_address': '0x434d5875534d19fc7105281cf61dbfd1c93c8cb1',
#   'name': 'CharPunk.Com',
#   'symbol': 'C',
#   'Numbers': 6.0},
#  {'token_address': '0x4092678e4e78230f46a1534c0fbc8fa39780892b',
#   'name': 'OCoin',
#   'symbol': 'OCN',
#   'Numbers': 6.0},
#  {'token_address': '0xeb4c2781e4eba804ce9a9803c67d0893436bb27d',
#   'name': 'renBTC',
#   'symbol': 'renBTC',
#   'Numbers': 5.0000425},
#  {'token_address': '0x35bd01fc9d6d5d81ca9e055db88dc49aa2c699a8',
#   'name': 'Friends With Benefits Pro',
#   'symbol': 'FWB',
#   'Numbers': 5.0},
#  {'token_address': '0xaf47ebbd460f21c2b3262726572ca8812d7143b0',
#   'name': 'Promodl',
#   'symbol': 'PMOD',
#   'Numbers': 5.0},
#  {'token_address': '0xe4815ae53b124e7263f08dcdbbb757d41ed658c6',
#   'name': 'Zks',
#   'symbol': 'ZKS',
#   'Numbers': 3.0},
#  {'token_address': '0x58b6a8a3302369daec383334672404ee733ab239',
#   'name': 'Livepeer Token',
#   'symbol': 'LPT',
#   'Numbers': 2.1218320149988203},
#  {'token_address': '0x79986af15539de2db9a5086382daeda917a9cf0c',
#   'name': None,
#   'symbol': None,
#   'Numbers': 1.0},
#  {'token_address': '0x8285ed6158579c7f280eaa7c80a5bacc42114921',
#   'name': ' GAntiMatter.Finance ETH Perpetual Bull Token Floor 1500USDC Cap 6000USDC',
#   'symbol': '+ETH($1500)',
#   'Numbers': 1.0},
#  {'token_address': '0x3e91a4c4ce0d6beb50b8bb140accffad080f66ad',
#   'name': 'CORNDAPP',
#   'symbol': 'CORNDAPP',
#   'Numbers': 1.0},
#  {'token_address': '0xfd79c2aa42ab4bfbd7c03c1e6866491172917b32',
#   'name': 'CryptoBotsBattle',
#   'symbol': 'CBTB',
#   'Numbers': 1.0},
#  {'token_address': '0x5f5d0767fb8ba2c2793bf7957993a63b5e67d92b',
#   'name': 'CryptoBots: Idle Token',
#   'symbol': 'CBIT',
#   'Numbers': 1.0},
#  {'token_address': '0x5a8728c23004ac748d5deb30748cb183917beff3',
#   'name': 'PIGCOIN',
#   'symbol': 'PGC2',
#   'Numbers': 1.0},
#  {'token_address': '0x69bbc3f8787d573f1bbdd0a5f40c7ba0aee9bcc9',
#   'name': 'YUP',
#   'symbol': 'YUP',
#   'Numbers': 0.6},
#  {'token_address': '0x7fc66500c84a76ad7e9c93437bfc5ac33e2ddae9',
#   'name': 'Aave Token',
#   'symbol': 'AAVE',
#   'Numbers': 0.57},
#  {'token_address': '0xfd4f241851be224e52ffc6947f0ee02579875049',
#   'name': 'Wrapped BTC',
#   'symbol': 'WBTC',
#   'Numbers': 0.28587529},
#  {'token_address': '0x2260fac5e5542a773aa44fbcfedf7c193bc2c599',
#   'name': 'Wrapped BTC',
#   'symbol': 'WBTC',
#   'Numbers': 0.23},
#  {'token_address': '0x62b9c7356a2dc64a1969e19c23e4f579f9810aa7',
#   'name': 'Convex CRV',
#   'symbol': 'cvxCRV',
#   'Numbers': 0.000361384344461034},
#  {'token_address': '0xff17171e320d5b997fef6232902c3bcc327f8b05',
#   'name': 'DiamondHands',
#   'symbol': 'HODL',
#   'Numbers': 1e-08},
#  {'token_address': '0x74cac868f2254f1a6b7ca951f0d86eac4a65c132',
#   'name': 'B Wrapped Ether',
#   'symbol': 'bWETH',
#   'Numbers': 3.9e-17}]

# %% [markdown]
# ## Add Liquidity Prices to list

# %%
""" Lowest Prices"""
price_params = {
    'chain': 'eth',
}

# %%
for r in erc20_result_list:
    price_url = f"https://deep-index.moralis.io/api/v2/erc20/{r['token_address']}/price"
    price_response = requests.get(price_url, headers=headers, params=price_params)
    if price_response.status_code == 200:
        price_response = json.loads(price_response.text)
        r['price'] = float(price_response["usdPrice"])
    else:
        r['price'] = 0

# %%
# Sort by value
erc20_result_list = sorted(erc20_result_list, key = lambda r: r['Numbers']*r['price'], reverse = True)
erc20_result_list
# Out:
# [{'token_address': '0x4b3464fe6a37ce9cfe2956056f447261fd7ea614',
#   'name': 'Rabbit Rocket',
#   'symbol': 'Rabbit',
#   'Numbers': 44758912878009.23,
#   'price': 1.38776508984949e+20},
#  {'token_address': '0xa3986e46f051e275e575930107848c4eba83a788',
#   'name': 'Squid Game V2',
#   'symbol': 'Squid Game V2',
#   'Numbers': 13907497505997.0,
#   'price': 3.469412724623725e+20},
#  {'token_address': '0x14026711b9b89f699916f608fa997944e3269f20',
#   'name': 'Monkeyverse',
#   'symbol': 'MONKE',
#   'Numbers': 331362.2029020689,
#   'price': 1.1548903326567561e+19},
#  {'token_address': '0x9b4109cfbf22348260db8d36780554d7fd3898ff',
#   'name': 'Subway Metaverse',
#   'symbol': 'Subway',
#   'Numbers': 6077755441.46719,
#   'price': 0.1999051721508243},
#  {'token_address': '0x9fc499e6215f2aa51b61eae1cfffdf52418bf712',
#   'name': 'Disney Metaverse',
#   'symbol': 'DISNEY',
#   'Numbers': 1579537761076.001,
#   'price': 0.000215076439955088},
#  {'token_address': '0xf71ba4058c7ea23992a2311add6862d854b3d229',
#   'name': 'MAYC COIN',
#   'symbol': 'MAYC',
#   'Numbers': 1708211504684.831,
#   'price': 0.000157012741159548},
#  {'token_address': '0xe29cca6ae51d4b815ccf084b0f7154e2092e9621',
#   'name': 'Cool Cats Coin',
#   'symbol': 'Cool Cats',
#   'Numbers': 1068353860538.7018,
#   'price': 0.000181829869025108},
#  {'token_address': '0x7cb05d1d1ffff52a0aa6143988a11927e599384d',
#   'name': 'Powell DAO',
#   'symbol': 'Powell',
#   'Numbers': 734901753974.8658,
#   'price': 0.000180672135241016},
#  {'token_address': '0xd3bf5b01aed2546645708ccbfc1ac0753089eaec',
#   'name': 'Nikeland Metaverse',
#   'symbol': 'Nikeland',
#   'Numbers': 1602384558800.8508,
#   'price': 7.5093927462436e-05},
#  {'token_address': '0x288c72aab7e6d1f688964c95404bc34dc0978528',
#   'name': 'Apple metaverse',
#   'symbol': 'APPLE',
#   'Numbers': 1004936007735.3873,
#   'price': 0.000116784645936593},
#  {'token_address': '0xf27adb015958b4f02128ecfa3ce59b3772e9676a',
#   'name': 'Harvard Metaverse',
#   'symbol': 'Harvard',
#   'Numbers': 2116467992977.0798,
#   'price': 5.1501454239991e-05},
#  {'token_address': '0xa227de65722742aa9269ec5d4d2a99c45b35cc5f',
#   'name': 'Punk Coin',
#   'symbol': 'Punk',
#   'Numbers': 616134464391.1177,
#   'price': 0.000160015623647161},
#  {'token_address': '0x22e845cbbafda629c0401de5f23e3f73b0cfa68a',
#   'name': 'BAYC Token',
#   'symbol': 'BAYC',
#   'Numbers': 583902944208.0671,
#   'price': 0.000111504556922759},
#  {'token_address': '0x3972e6316c23fbdb98906b627c43e335642cddf3',
#   'name': 'HelloKitty Metaverse',
#   'symbol': 'HelloKitty',
#   'Numbers': 577467734607.1366,
#   'price': 9.3435954269277e-05},
#  {'token_address': '0xce4fd7ea4c894ed145ecb996a79c336f3a279334',
#   'name': 'Mfers Coin',
#   'symbol': 'Mfers',
#   'Numbers': 1825479101141.389,
#   'price': 2.763443078751e-05},
#  {'token_address': '0x205c58815d158b38e42b979a81a740dfb2eff15c',
#   'name': 'NASA Metaverse',
#   'symbol': 'NASA',
#   'Numbers': 1097965502695.7126,
#   'price': 4.1140534120665e-05},
#  {'token_address': '0xe44c8ee0622647d2563a8b2732941772328a751b',
#   'name': 'Imaginary Ones',
#   'symbol': 'Imaginary Ones',
#   'Numbers': 1459220681844.6455,
#   'price': 1.6088398193509e-05},
#  {'token_address': '0x41e38882257d0a318c8fb5f1c4e4f50a0b85f56e',
#   'name': 'LG Metaverse',
#   'symbol': 'LG',
#   'Numbers': 1287311286941.4475,
#   'price': 1.4693363763551e-05},
#  {'token_address': '0x4e22eb365dcc6f34ae14f8800203dfe3fda2df4e',
#   'name': 'Invisible Friends',
#   'symbol': 'Invisible',
#   'Numbers': 1176457174280.8801,
#   'price': 1.3167984093955e-05},
#  {'token_address': '0xfab905850bb61af584dc5c7030479ee7a44a2f0a',
#   'name': 'CryptoPunks',
#   'symbol': 'CryptoPunks',
#   'Numbers': 889411647361.3843,
#   'price': 1.3110428718074e-05},
#  {'token_address': '0x6981b63574ce3c5d3987179a417c7b66feb5d579',
#   'name': 'BombCrypto',
#   'symbol': 'B0MB3R',
#   'Numbers': 250000000000.0,
#   'price': 4.6594498488005e-05},
#  {'token_address': '0x7be1520709f0bce6b43e07b172db49fd7b944876',
#   'name': 'Red Bull Metaverse',
#   'symbol': 'RedBull',
#   'Numbers': 499043557467.50476,
#   'price': 2.2220862481362e-05},
#  {'token_address': '0x013bb7458f51b2e4c06eed814b8ef353dac947e9',
#   'name': 'SEGA Metaverse',
#   'symbol': 'SEGA',
#   'Numbers': 90911001.36240952,
#   'price': 0.11020769345657301},
#  {'token_address': '0x4f22dd9cc043518446d5d0fdca82d00a5563a399',
#   'name': 'BAKC COIN',
#   'symbol': 'BAKC',
#   'Numbers': 818297349314.0883,
#   'price': 1.1744632053078e-05},
#  {'token_address': '0x1220902299fc2807dd6fa4a0900ae34bc11bed5e',
#   'name': 'World Of Women',
#   'symbol': 'World Of Women',
#   'Numbers': 1148198586583.1704,
#   'price': 6.947773360769e-06},
#  {'token_address': '0x5afc8f7374f501669a3a6693fa7e6c0df7bd819d',
#   'name': 'CLONE X',
#   'symbol': 'CLONE',
#   'Numbers': 578771364048.3153,
#   'price': 1.0380021527717e-05},
#  {'token_address': '0x7841479c5976b8184dbcde9a7a5113901b233efb',
#   'name': 'STEPN Governance Token',
#   'symbol': 'GMT',
#   'Numbers': 900000000000.0,
#   'price': 4.86521225546e-06},
#  {'token_address': '0xe87e0ee01aa0e836f005e67c251a56e1c17237f2',
#   'name': 'DeBank DAO',
#   'symbol': 'DBD',
#   'Numbers': 61946145446.99648,
#   'price': 6.6465192324612e-05},
#  {'token_address': '0xd49717013d7d752b457e603ef6fca7f0cddb1745',
#   'name': 'DairyQueen Metaverse',
#   'symbol': 'DairyQueen',
#   'Numbers': 99301254229.34152,
#   'price': 3.6630364875903e-05},
#  {'token_address': '0x265befe2b1a0f4f646dea96ba09c1656b74bda91',
#   'name': 'abSHIBA.com',
#   'symbol': 'ABSHIBA.com',
#   'Numbers': 17648460.0,
#   'price': 0.18609368546123034},
#  {'token_address': '0xcf4b20e54c094c758cb109805e2fa5c378a08afe',
#   'name': 'Shiba Inu Hodler',
#   'symbol': 'SHIBAHODLER',
#   'Numbers': 28091749526.142036,
#   'price': 9.8158092525184e-05},
#  {'token_address': '0xb7de3bb824a17e309134d913f354d29a04fec457',
#   'name': 'Verizon Metaverse',
#   'symbol': 'Verizon',
#   'Numbers': 763649219850.1014,
#   'price': 3.388769734072e-06},
#  {'token_address': '0xde5b34a43929192a3dded8b9391d3a5cb4b7270e',
#   'name': 'MetaMask DAO',
#   'symbol': 'METADAO',
#   'Numbers': 39252546604.35483,
#   'price': 6.2904018974614e-05},
#  {'token_address': '0x4d224452801aced8b2f0aebe155379bb5d594381',
#   'name': 'ApeCoin',
#   'symbol': 'APE',
#   'Numbers': 196457.87678914264,
#   'price': 12.269018849800785},
#  {'token_address': '0xe5d89696d170a5af25d38ffb96b6539a0b537653',
#   'name': 'Bikini Metaverse',
#   'symbol': 'Bikini',
#   'Numbers': 830327027861.0763,
#   'price': 2.737872834763e-06},
#  {'token_address': '0x3432b6a60d23ca0dfca7761b7ab56459d9c964d0',
#   'name': 'Frax Share',
#   'symbol': 'FXS',
#   'Numbers': 48814.41327088753,
#   'price': 38.16506433542234},
#  {'token_address': '0xf5c6e17e6cbd61b4a3d2ce321161ef4bdad2c12f',
#   'name': 'Riot Games',
#   'symbol': 'Riot',
#   'Numbers': 73540581155.059,
#   'price': 2.3906415906327e-05},
#  {'token_address': '0x596651f20ea621e2af6ed1e3cefc4511c91181ee',
#   'name': 'Gear DAO',
#   'symbol': 'GEAR',
#   'Numbers': 5843347027.903645,
#   'price': 0.000270329067654453},
#  {'token_address': '0x8ee84fed29b2e7161d373976c5a13e933793ca3e',
#   'name': 'Amazon Metaverse',
#   'symbol': 'Amazon',
#   'Numbers': 525322384592.06995,
#   'price': 2.582116031242e-06},
#  {'token_address': '0xe50a082a2853ab88820852ce8b6bab0346050954',
#   'name': 'POAP Dao',
#   'symbol': 'POAPDAO',
#   'Numbers': 5108430276.320326,
#   'price': 0.00022407815734927},
#  {'token_address': '0x59bd59e1473271ad037faf1fe5fb821522d7aade',
#   'name': 'Coinbase DAO',
#   'symbol': 'COINBASE',
#   'Numbers': 4559193105.827674,
#   'price': 0.000229591520177792},
#  {'token_address': '0x1cf20d6bdfd76487487fbd417a46198f6d5b96b7',
#   'name': 'MetaMask DAO',
#   'symbol': 'MaskDAO',
#   'Numbers': 21028471757.579247,
#   'price': 4.7485100538183e-05},
#  {'token_address': '0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48',
#   'name': 'USD Coin',
#   'symbol': 'USDC',
#   'Numbers': 884013.05118,
#   'price': 1.001601200560182},
#  {'token_address': '0x6b5b49a4dff73e9b9d7032eac608914f8cccbc8a',
#   'name': 'PHILIPS Metaverse',
#   'symbol': 'PHILIPS',
#   'Numbers': 4991893142.407146,
#   'price': 0.000158163023807283},
#  {'token_address': '0x82dfdb2ec1aa6003ed4acba663403d7c2127ff67',
#   'name': 'akSwap.io',
#   'symbol': 'akSwap.io',
#   'Numbers': 1000000.0,
#   'price': 0.6600922525570115},
#  {'token_address': '0x1412eca9dc7daef60451e3155bb8dbf9da349933',
#   'name': 'A68.net',
#   'symbol': 'A68.net',
#   'Numbers': 563935.68,
#   'price': 1.1316832808442432},
#  {'token_address': '0x78785f09deb083ff9c1ac3cce023c903e3b0d9bf',
#   'name': 'Shiba Dao',
#   'symbol': 'SHIBADAO',
#   'Numbers': 1808538942.1618507,
#   'price': 0.000335812730998002},
#  {'token_address': '0xc85e0474068dba5b49450c26879541ee6cc94554',
#   'name': 'KyDy.org',
#   'symbol': 'KyDy.org',
#   'Numbers': 600000.0,
#   'price': 0.9611986310940369},
#  {'token_address': '0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2',
#   'name': 'Wrapped Ether',
#   'symbol': 'WETH',
#   'Numbers': 145.92100152811994,
#   'price': 3510.0813086111134},
#  {'token_address': '0xf9d25eb4c75ed744596392cf89074afaa43614a8',
#   'name': 'Up1.org',
#   'symbol': 'Up1.org',
#   'Numbers': 565270.0,
#   'price': 0.8911100592879843},
#  {'token_address': '0x34278f6f40079eae344cbac61a764bcf85afc949',
#   'name': 'FF9.io',
#   'symbol': 'FF9.io',
#   'Numbers': 900000.0,
#   'price': 0.4172005291026829},
#  {'token_address': '0x33bd8d4b90e3632742cd0d741f95e9453ae49f92',
#   'name': 'Gameloft Metaverse',
#   'symbol': 'Gameloft',
#   'Numbers': 3477357159.0511284,
#   'price': 0.000102872149245207},
#  {'token_address': '0xdce8b8bd8889ae97933f9bb33632bb4b2b763bb1',
#   'name': 'Ubisoft Metaverse',
#   'symbol': 'Ubisoft',
#   'Numbers': 21354113765.942543,
#   'price': 1.4977507453841e-05},
#  {'token_address': '0x2a3bff78b79a009976eea096a51a948a3dc00e34',
#   'name': 'Wilder',
#   'symbol': 'WILD',
#   'Numbers': 154967.06817972657,
#   'price': 1.7675142230190612},
#  {'token_address': '0xb699dab9b3f981a01abc0474f085427d20d0d602',
#   'name': 'YeSwap.net',
#   'symbol': 'YeSwap.net',
#   'Numbers': 600000.0,
#   'price': 0.3960447770816635},
#  {'token_address': '0xeb4c2781e4eba804ce9a9803c67d0893436bb27d',
#   'name': 'renBTC',
#   'symbol': 'renBTC',
#   'Numbers': 5.0000425,
#   'price': 46628.30089420613},
#  {'token_address': '0xa5a711c6b34f41164fe94d997c9e3ac0c4617e8c',
#   'name': 'Big Green Dao',
#   'symbol': 'BGD',
#   'Numbers': 476345441.0022563,
#   'price': 0.00046376992425089},
#  {'token_address': '0xa91827215697bb20d142bf46db3d1bfd8f5264dc',
#   'name': 'Mastercard Metaverse',
#   'symbol': 'Mastercard',
#   'Numbers': 1293734913.9516604,
#   'price': 0.000151099253085437},
#  {'token_address': '0x978d20bc2a6767917c9f48c7a4c5e95961802453',
#   'name': 'SUPA  Foundation',
#   'symbol': 'SUPA',
#   'Numbers': 505296437.19195354,
#   'price': 0.000377242778425942},
#  {'token_address': '0x0ec78ed49c2d27b315d462d43b5bab94d2c79bf8',
#   'name': 'ZERO',
#   'symbol': 'ZERO',
#   'Numbers': 612480.7822037557,
#   'price': 0.3086835659852256},
#  {'token_address': '0x6a1dc48a348740b62ed7a7943d53d9c84f35b326',
#   'name': 'Skype Metaverse',
#   'symbol': 'Skype',
#   'Numbers': 3988244616.848803,
#   'price': 4.4316707836e-05},
#  {'token_address': '0xcbdeb4ff6cb834a83bf438d26a2fb5e6f53319b7',
#   'name': 'PunkETH.io',
#   'symbol': 'NFT',
#   'Numbers': 6.0,
#   'price': 29400.226088612308},
#  {'token_address': '0xa04e18e86408fa651c144f10de5236493d070e78',
#   'name': 'Amazon Metaverse',
#   'symbol': 'Amazon',
#   'Numbers': 522792983.79448485,
#   'price': 0.000335974246445481},
#  {'token_address': '0x9ddec70ab6ff39491c449d5ce3a02a852dc8b80a',
#   'name': 'Richard Mille Metaverse',
#   'symbol': 'Richard Mille',
#   'Numbers': 1275044549.833596,
#   'price': 0.000134436844287971},
#  {'token_address': '0xbcca60bb61934080951369a648fb03df4f96263c',
#   'name': 'Aave interest bearing USDC',
#   'symbol': 'aUSDC',
#   'Numbers': 164623.999074,
#   'price': 1.0034056178934587},
#  {'token_address': '0xe80c0cd204d654cebe8dd64a4857cab6be8345a3',
#   'name': 'JPEG’d Governance Token',
#   'symbol': 'JPEG',
#   'Numbers': 46946708.02572082,
#   'price': 0.003326907533157802},
#  {'token_address': '0x0391d2021f89dc339f60fff84546ea23e337750f',
#   'name': 'BarnBridge Governance Token',
#   'symbol': 'BOND',
#   'Numbers': 10000.0,
#   'price': 12.726360373550818},
#  {'token_address': '0x01454cdc3fab2a026cc7d1cb2aea9b909d5ba0ee',
#   'name': 'deApy.org',
#   'symbol': 'deApy.org',
#   'Numbers': 300000.0,
#   'price': 0.42110706347716353},
#  {'token_address': '0xffa55849a7309c7f4fb4de88d804fd546a66c271',
#   'name': 'DyDex.io',
#   'symbol': 'DyDex.io',
#   'Numbers': 300000.0,
#   'price': 0.41042191564646907},
#  {'token_address': '0xf12ce5503e4bedb7178951321925e4306c4c3b12',
#   'name': 'SupDao.com',
#   'symbol': 'SupDao.com',
#   'Numbers': 799999.9999999999,
#   'price': 0.1522502468740497},
#  {'token_address': '0xd667a84005975eef906e980f200541974a8c9766',
#   'name': 'WxFi.io',
#   'symbol': 'WxFi.io',
#   'Numbers': 300000.0,
#   'price': 0.40494334906161883},
#  {'token_address': '0x5d7274dff3ac2549ba47024745c202b588099179',
#   'name': 'Mini FLOKI Token',
#   'symbol': 'Mini FLOKI',
#   'Numbers': 1279500000.0,
#   'price': 9.1394375654526e-05},
#  {'token_address': '0x0000000000095413afc295d19edeb1ad7b71c952',
#   'name': 'Tokenlon',
#   'symbol': 'LON',
#   'Numbers': 22800.0,
#   'price': 4.776100717106843},
#  {'token_address': '0x41a014616bbbc9ebba81cd23a884b2d300045d48',
#   'name': 'COCA COLA Metaverse',
#   'symbol': 'COCA COLA',
#   'Numbers': 522792983.79448485,
#   'price': 0.000150715530699855},
#  {'token_address': '0xe4a581c3e7038957f628027ee1249fdd5fdb2969',
#   'name': 'DreamWorks Metaverse',
#   'symbol': 'DreamWorks',
#   'Numbers': 3073970255.05153,
#   'price': 2.52266589626e-05},
#  {'token_address': '0x4af9ab04615cb91e2ee8cbedb43fb52ed205041b',
#   'name': 'KHEX.net',
#   'symbol': 'KHEX.net',
#   'Numbers': 484642.0,
#   'price': 0.15841949406369774},
#  {'token_address': '0xefd6c64533602ac55ab64442307f6fe2c9307305',
#   'name': 'APE',
#   'symbol': 'APE',
#   'Numbers': 38482589.90208715,
#   'price': 0.001920398863409603},
#  {'token_address': '0xe1b3f4849c8959f53edd3ab932e0f145daf865c1',
#   'name': 'Key7.net',
#   'symbol': 'Key7.net',
#   'Numbers': 294402.0,
#   'price': 0.24081643766376962},
#  {'token_address': '0x6b3595068778dd592e39a122f4f5a5cf09c90fe2',
#   'name': 'SushiToken',
#   'symbol': 'SUSHI',
#   'Numbers': 16039.983214239339,
#   'price': 4.359376439785814},
#  {'token_address': '0xba5bde662c17e2adff1075610382b9b691296350',
#   'name': 'SuperRare',
#   'symbol': 'RARE',
#   'Numbers': 101271.29007954283,
#   'price': 0.6855194016716576},
#  {'token_address': '0x20806e0c9b9f7b65d59a9959f029eb752196bdc5',
#   'name': 'Lentil Eater',
#   'symbol': 'LENTIL',
#   'Numbers': 1455682397.2300644,
#   'price': 4.4586260722246e-05},
#  {'token_address': '0x606375881d98452478b265b577840185511353f3',
#   'name': 'Walmart Metaverse',
#   'symbol': 'Walmart',
#   'Numbers': 522792983.79448485,
#   'price': 0.000108328530303696},
#  {'token_address': '0x2ceee24f8d03fc25648c68c8e6569aa0512f6ac3',
#   'name': 'ABCHANGE.io',
#   'symbol': 'XCH',
#   'Numbers': 894393.0,
#   'price': 0.062397324806374624},
#  {'token_address': '0x8798249c2e607446efb7ad49ec89dd1865ff4272',
#   'name': 'SushiBar',
#   'symbol': 'xSUSHI',
#   'Numbers': 8582.793879503026,
#   'price': 5.581829943861847},
#  {'token_address': '0x46adf9e560d22c8c6ab028052f8cf0b0b97a55d2',
#   'name': 'Supercell Metaverse',
#   'symbol': 'Supercell',
#   'Numbers': 3736702692.3245883,
#   'price': 1.199321899684e-05},
#  {'token_address': '0x77b7340faa3d8f75eed612d051b64a5a5f6167f3',
#   'name': 'NEW YORK COIN',
#   'symbol': 'NEW YORK',
#   'Numbers': 522792983.79448485,
#   'price': 7.0865261243724e-05},
#  {'token_address': '0xf0a06c0612591c8de92ae4fe448426f9094ee823',
#   'name': 'AzukiCoin',
#   'symbol': 'Azuki',
#   'Numbers': 2880720210.038291,
#   'price': 1.0902238788673e-05},
#  {'token_address': '0x08164ee2dda4e8aab7a42ccc13aadd2b296395ae',
#   'name': 'ApeCoin',
#   'symbol': 'APE',
#   'Numbers': 1177766.8374036117,
#   'price': 0.024850711210042356},
#  {'token_address': '0xf39e77f4f46f1784cbd4fd39ebde4753870104f8',
#   'name': 'Target Metaverse',
#   'symbol': 'Target',
#   'Numbers': 2730271374.92686,
#   'price': 9.493286856414e-06},
#  {'token_address': '0x07d5e4db69cb04032ed7c92109fcb5a3e8dc47fa',
#   'name': 'Pokemon Metaverse',
#   'symbol': 'Pokemon',
#   'Numbers': 1923987848.3456721,
#   'price': 1.2788840483719e-05},
#  {'token_address': '0xd2f91aafce21131173a6efbc9801445be0b71c71',
#   'name': 'Nike Metaverse',
#   'symbol': 'Nike',
#   'Numbers': 522792983.79448485,
#   'price': 4.4985115578924e-05},
#  {'token_address': '0x1884f9eda99ca66c72d6fecdfbf9689d6bbe3b03',
#   'name': 'XBOX Metaverse',
#   'symbol': 'XBOX',
#   'Numbers': 1788266029.9146285,
#   'price': 1.2669256063657e-05},
#  {'token_address': '0x72c07d9151dce2ea862595487ef7e21cc312e564',
#   'name': 'Zapper.Fi',
#   'symbol': 'ZAPP',
#   'Numbers': 985498.5352449248,
#   'price': 0.022117738687076588},
#  {'token_address': '0x3b484b82567a09e2588a13d54d032153f0c0aee0',
#   'name': 'SOS',
#   'symbol': 'SOS',
#   'Numbers': 10176246571.219704,
#   'price': 1.869690067494e-06},
#  {'token_address': '0xdc98c5543f3004debfaad8966ec403093d0aa4a8',
#   'name': 'Etherrock #72',
#   'symbol': 'PEBBLE',
#   'Numbers': 72000000.0,
#   'price': 0.000213051920370317},
#  {'token_address': '0x9f14db5a794565d952f01e65600793bee20e9269',
#   'name': 'Layer 3',
#   'symbol': 'L3T',
#   'Numbers': 1350381.0262976869,
#   'price': 0.009664293189250191},
#  {'token_address': '0x2260fac5e5542a773aa44fbcfedf7c193bc2c599',
#   'name': 'Wrapped BTC',
#   'symbol': 'WBTC',
#   'Numbers': 0.23,
#   'price': 46215.170845232504},
#  {'token_address': '0xc18360217d8f7ab5e7c516566761ea12ce7f9d72',
#   'name': 'Ethereum Name Service',
#   'symbol': 'ENS',
#   'Numbers': 387.98550488042326,
#   'price': 20.398306320093567},
#  {'token_address': '0xcb56b52316041a62b6b5d0583dce4a8ae7a3c629',
#   'name': 'Cigarette Token',
#   'symbol': 'CIG',
#   'Numbers': 1600000.0,
#   'price': 0.004724329612654311},
#  {'token_address': '0x64d91f12ece7362f91a6f8e7940cd55f05060b92',
#   'name': 'Burn',
#   'symbol': 'ASH',
#   'Numbers': 795.5012349210117,
#   'price': 7.50599369371257},
#  {'token_address': '0xee3b9b531f4c564c70e14b7b3bb7d516f33513ff',
#   'name': 'DeFi Omega',
#   'symbol': 'DFIO',
#   'Numbers': 500.0,
#   'price': 7.653399488914123},
#  {'token_address': '0xa2cd3d43c775978a96bdbf12d733d5a1ed94fb18',
#   'name': 'Chain',
#   'symbol': 'XCN',
#   'Numbers': 55737.70491803,
#   'price': 0.06626710523473943},
#  {'token_address': '0x2e41d4c356cc98a49e72d8f461141fc96878aa1d',
#   'name': 'ApeX',
#   'symbol': 'APX',
#   'Numbers': 10451877.56150357,
#   'price': 0.000352257852544695},
#  {'token_address': '0xe54a0e24d604af7489eaf4c12a85a89fa0bb0cc7',
#   'name': 'Doodles',
#   'symbol': 'DOODLE',
#   'Numbers': 99999.99999999999,
#   'price': 0.024905889554788258},
#  {'token_address': '0xd9c082b563cbddc7698d0843ccb320486e724148',
#   'name': 'Terraswap',
#   'symbol': 'TSP',
#   'Numbers': 240481.4249665821,
#   'price': 0.008943020331248837},
#  {'token_address': '0x5a35a6686db167b05e2eb74e1ede9fb5d9cdb3e0',
#   'name': 'Cigarette Token',
#   'symbol': 'CIG',
#   'Numbers': 1200000.0,
#   'price': 0.001752152849047275},
#  {'token_address': '0x434d5875534d19fc7105281cf61dbfd1c93c8cb1',
#   'name': 'CharPunk.Com',
#   'symbol': 'C',
#   'Numbers': 6.0,
#   'price': 271.05491152048586},
#  {'token_address': '0x426ca1ea2406c07d75db9585f22781c096e3d0e0',
#   'name': 'Minereum',
#   'symbol': 'MNE',
#   'Numbers': 32000.0,
#   'price': 0.05072935715879872},
#  {'token_address': '0xb639687c6768ab33996541d05948dd621a012503',
#   'name': 'Discord DAO',
#   'symbol': 'Discord',
#   'Numbers': 8977496578.878891,
#   'price': 1.27607887452e-07},
#  {'token_address': '0xf4d2888d29d722226fafa5d9b24f9164c092421e',
#   'name': 'LooksRare Token',
#   'symbol': 'LOOKS',
#   'Numbers': 200.0,
#   'price': 2.349634846641785},
#  {'token_address': '0xdac17f958d2ee523a2206206994597c13d831ec7',
#   'name': 'Tether USD',
#   'symbol': 'USDT',
#   'Numbers': 288.000005,
#   'price': 1.0033052854589521},
#  {'token_address': '0x35bd01fc9d6d5d81ca9e055db88dc49aa2c699a8',
#   'name': 'Friends With Benefits Pro',
#   'symbol': 'FWB',
#   'Numbers': 5.0,
#   'price': 52.8049172995506},
#  {'token_address': '0x91138bdb14afa919e7204ccd1f668411c22d91f0',
#   'name': 'FUCK DAO',
#   'symbol': 'Fuck',
#   'Numbers': 2792983.794484848,
#   'price': 6.8666298986847e-05},
#  {'token_address': '0xb1a2efe104e253cb36a7b26eeaf9c20cc2c56130',
#   'name': 'Lens Protocol',
#   'symbol': 'LENS',
#   'Numbers': 570380.9181073976,
#   'price': 0.000278034071004093},
#  {'token_address': '0x667fd83e24ca1d935d36717d305d54fa0cac991c',
#   'name': 'Collector Coin',
#   'symbol': 'AGS',
#   'Numbers': 1000.0,
#   'price': 0.14028220255227672},
#  {'token_address': '0x7fc66500c84a76ad7e9c93437bfc5ac33e2ddae9',
#   'name': 'Aave Token',
#   'symbol': 'AAVE',
#   'Numbers': 0.57,
#   'price': 240.47797783569},
#  {'token_address': '0x12e56851ec22874520dc4c7fa0a8a8d7dba1bac8',
#   'name': 'GEN.ART',
#   'symbol': 'GENART',
#   'Numbers': 1491.0,
#   'price': 0.046866865939465756},
#  {'token_address': '0x4ab16cdc82a4ea4727ab40caee1bb46622c13641',
#   'name': 'Sablier: Governance Token',
#   'symbol': 'SABLIER',
#   'Numbers': 6663.292618365543,
#   'price': 0.00967972774451655},
#  {'token_address': '0x58b6a8a3302369daec383334672404ee733ab239',
#   'name': 'Livepeer Token',
#   'symbol': 'LPT',
#   'Numbers': 2.1218320149988203,
#   'price': 29.02722651973012},
#  {'token_address': '0xfd4f241851be224e52ffc6947f0ee02579875049',
#   'name': 'Wrapped BTC',
#   'symbol': 'WBTC',
#   'Numbers': 0.28587529,
#   'price': 185.38250602245904},
#  {'token_address': '0x329d75f6d8a95b23b021665db5d63e93e0f1079a',
#   'name': 'OpenSea',
#   'symbol': 'OPEN',
#   'Numbers': 4352.9157743177875,
#   'price': 0.00821812519423853},
#  {'token_address': '0x382f2991a93462905a8b8b65adfcec37b99db711',
#   'name': 'BEANZ Official',
#   'symbol': 'BEANZ',
#   'Numbers': 10000.0,
#   'price': 0.00283587726426197},
#  {'token_address': '0xe0736f3f455f1dbd29bf6f8346ead22f5cf78d08',
#   'name': 'Foundation',
#   'symbol': 'FND',
#   'Numbers': 1115209.2857715164,
#   'price': 1.0099726710413e-05},
#  {'token_address': '0x1bbb57def2f6192f0b9b8565f49034bf1fcdb604',
#   'name': 'StackToken',
#   'symbol': 'STACK',
#   'Numbers': 414.0,
#   'price': 0.002807855230325276},
#  {'token_address': '0x69bbc3f8787d573f1bbdd0a5f40c7ba0aee9bcc9',
#   'name': 'YUP',
#   'symbol': 'YUP',
#   'Numbers': 0.6,
#   'price': 0.8329856112413989},
#  {'token_address': '0xe4815ae53b124e7263f08dcdbbb757d41ed658c6',
#   'name': 'Zks',
#   'symbol': 'ZKS',
#   'Numbers': 3.0,
#   'price': 0.11177694780400972},
#  {'token_address': '0x8c4e7f814d40f8929f9112c5d09016f923d34472',
#   'name': 'XCELTOKEN PLUS',
#   'symbol': 'XLAB',
#   'Numbers': 100.0,
#   'price': 0.000358385739277224},
#  {'token_address': '0x2f141ce366a2462f02cea3d12cf93e4dca49e4fd',
#   'name': 'Free Coin',
#   'symbol': 'FREE',
#   'Numbers': 10000.0,
#   'price': 6.5111136704e-07},
#  {'token_address': '0x4092678e4e78230f46a1534c0fbc8fa39780892b',
#   'name': 'OCoin',
#   'symbol': 'OCN',
#   'Numbers': 6.0,
#   'price': 0.001071033185848498},
#  {'token_address': '0x62b9c7356a2dc64a1969e19c23e4f579f9810aa7',
#   'name': 'Convex CRV',
#   'symbol': 'cvxCRV',
#   'Numbers': 0.000361384344461034,
#   'price': 2.5770757141779668},
#  {'token_address': '0x657c9bd6dd653ba3de3eb95b88ddfdeea1f4ea76',
#   'name': 'Bored Ape DAO',
#   'symbol': 'Ape DAO',
#   'Numbers': 200000.0,
#   'price': 1.5687054e-11},
#  {'token_address': '0xff17171e320d5b997fef6232902c3bcc327f8b05',
#   'name': 'DiamondHands',
#   'symbol': 'HODL',
#   'Numbers': 1e-08,
#   'price': 1.9489915828818e-05},
#  {'token_address': '0x8e546846a9a15bbdb695599b32d5d2de37d151e4',
#   'name': 'Patek Philippe Metaverse',
#   'symbol': 'Patek Philippe',
#   'Numbers': 1052140369121.4131,
#   'price': 0},
#  {'token_address': '0xedd6b61a2e060a6f3d701b6cdac05f80cac15d5a',
#   'name': 'Nexon Metaverse',
#   'symbol': 'Nexon',
#   'Numbers': 822625181917.7892,
#   'price': 0},
#  {'token_address': '0x7c2d36abcb16ef57fb3624f3ebf9fa584e449e86',
#   'name': 'Epic Games Metaverse',
#   'symbol': 'Epic Games',
#   'Numbers': 133034946643.31796,
#   'price': 0},
#  {'token_address': '0x7e05540a61b531793742fde0514e6c136b5fbafe',
#   'name': 'FodlStake',
#   'symbol': 'xFODL',
#   'Numbers': 2126955.6642625616,
#   'price': 0},
#  {'token_address': '0xc12d1c73ee7dc3615ba4e37e4abfdbddfa38907e',
#   'name': 'KickToken',
#   'symbol': 'KICK',
#   'Numbers': 1777776.0,
#   'price': 0.0},
#  {'token_address': '0x028171bca77440897b824ca71d1c56cac55b68a3',
#   'name': 'Aave interest bearing DAI',
#   'symbol': 'aDAI',
#   'Numbers': 640668.3341002063,
#   'price': 0},
#  {'token_address': '0x3495ffcee09012ab7d827abf3e3b3ae428a38443',
#   'name': 'BeautyChain',
#   'symbol': 'BEC',
#   'Numbers': 571260.42,
#   'price': 0},
#  {'token_address': '0xc5d105e63711398af9bbff092d4b6769c82f793d',
#   'name': 'BeautyChain',
#   'symbol': 'BEC',
#   'Numbers': 502950.5,
#   'price': 0},
#  {'token_address': '0xfa327eb9111a5283167734efb637db46c990a27b',
#   'name': 'Euler Pool: Ribbon',
#   'symbol': 'eRBN',
#   'Numbers': 97624.64861708214,
#   'price': 0},
#  {'token_address': '0xfebc1195e47043e0d2c5791d7cd9519bb631e5c9',
#   'name': '8DAO TOKEN',
#   'symbol': '8DAO',
#   'Numbers': 40000.0,
#   'price': 0},
#  {'token_address': '0xb594f65151ff240e378c611dd68112df67bd420d',
#   'name': '8DAO TOKEN',
#   'symbol': '8DAO',
#   'Numbers': 40000.0,
#   'price': 0},
#  {'token_address': '0x808507121b80c02388fad14726482e061b8da827',
#   'name': 'Pendle',
#   'symbol': 'PENDLE',
#   'Numbers': 39946.41723771381,
#   'price': 0.0},
#  {'token_address': '0xc92e74b131d7b1d46e60e07f3fae5d8877dd03f0',
#   'name': 'Minereum',
#   'symbol': 'MNE',
#   'Numbers': 32000.0,
#   'price': 0},
#  {'token_address': '0xc1f5ba8bab3ca299f9817876a6715627f9e2b11a',
#   'name': 'FIFA.win',
#   'symbol': 'FIFAmini',
#   'Numbers': 20180.614,
#   'price': 0},
#  {'token_address': '0xcda7390c64c825c3c420ddd5721bc93bd156c08c',
#   'name': 'MAYCdao.io',
#   'symbol': 'MAYCdao.io',
#   'Numbers': 16665.0,
#   'price': 0},
#  {'token_address': '0xdfe7d03eac9a84e1a959d1a9245aa78baea8fd8b',
#   'name': 'BAKCdao.io',
#   'symbol': 'BAKCdao.io',
#   'Numbers': 11110.0,
#   'price': 0},
#  {'token_address': '0xcc3d334b20a37bf3ed79b1ab6a72efda23323822',
#   'name': 'cloneXdao.io',
#   'symbol': 'cloneXdao.io',
#   'Numbers': 11110.0,
#   'price': 0},
#  {'token_address': '0xbd8240c23ec98b21f38c5d3e1eea957ab80da9ca',
#   'name': 'BAYCcoin.io',
#   'symbol': 'APECOIN',
#   'Numbers': 5555.0,
#   'price': 0},
#  {'token_address': '0x9a271913906594a2dac3b7b4bd2ae0a99c3657bc',
#   'name': 'CoolCatsDAO.io',
#   'symbol': 'CoolCatsDAO.io',
#   'Numbers': 5555.0,
#   'price': 0},
#  {'token_address': '0x4b05e6e8cb88b69a971ffe8af2a7d7a21edf3afb',
#   'name': 'MurakamiDAO.io',
#   'symbol': 'MurakamiDAO.io',
#   'Numbers': 5555.0,
#   'price': 0},
#  {'token_address': '0xba5f00a28f732f23ba946c594716496ebdc9aef5',
#   'name': 'BKEX.COM Token',
#   'symbol': 'bkex.com',
#   'Numbers': 2018.0611000000001,
#   'price': 0},
#  {'token_address': '0xd3ace836e47f7cf4948dffd8ca2937494c52580c',
#   'name': 'Free BOB Tokens - BobsRepair.com',
#   'symbol': 'BOBx',
#   'Numbers': 1500.0,
#   'price': 0},
#  {'token_address': '0x7e9e431a0b8c4d532c745b1043c7fa29a48d4fba',
#   'name': 'eosDAC Community Owned EOS Block Producer ERC20 Tokens',
#   'symbol': 'eosDAC',
#   'Numbers': 1199.0,
#   'price': 0},
#  {'token_address': '0xd4ae0807740df6fbaa7a258907132a2ac8d52fbc',
#   'name': 'KEOSToken',
#   'symbol': 'KEOS',
#   'Numbers': 1199.0,
#   'price': 0},
#  {'token_address': '0x416935c684686877e3931fe8d766cafc5b398ebf',
#   'name': 'Cryptonex (CNX)',
#   'symbol': 'CNX',
#   'Numbers': 1000.0,
#   'price': 0},
#  {'token_address': '0x7b2f9706cd8473b4f5b7758b0171a9933fc6c4d6',
#   'name': 'An Etheal Promo',
#   'symbol': 'HEALP',
#   'Numbers': 911.0,
#   'price': 0},
#  {'token_address': '0xd4de05944572d142fbf70f3f010891a35ac15188',
#   'name': 'Bulleon Promo Token',
#   'symbol': 'BULLEON PROMO',
#   'Numbers': 365.0,
#   'price': 0},
#  {'token_address': '0xf6276830c265a779a2225b9d2fcbab790cbeb92b',
#   'name': 'XCELTOKEN',
#   'symbol': 'XCEL',
#   'Numbers': 200.0,
#   'price': 0},
#  {'token_address': '0x5eb87caa0105a63aa87a36c7bd2573bd13e84fae',
#   'name': 'BQT',
#   'symbol': 'BQT',
#   'Numbers': 143.2439,
#   'price': 0},
#  {'token_address': '0x07a5efd3c3a5c540b8ae5d8604d1487e5bac4c8e',
#   'name': 'HoweyCoin',
#   'symbol': 'HOW',
#   'Numbers': 100.0,
#   'price': 0},
#  {'token_address': '0xf509cdcdf44a0bcd2953ce3f03f4b433ef6e4c44',
#   'name': 'Fomoverse Token',
#   'symbol': 'FOMO',
#   'Numbers': 69.0,
#   'price': 0},
#  {'token_address': '0xb47e3cd837ddf8e4c57f05d70ab865de6e193bbb',
#   'name': 'CRYPTOPUNKS',
#   'symbol': 'Ͼ',
#   'Numbers': 68.0,
#   'price': 0},
#  {'token_address': '0xf230b790e05390fc8295f4d3f60332c93bed42e2',
#   'name': 'Tronix',
#   'symbol': 'TRX',
#   'Numbers': 61.0,
#   'price': 0},
#  {'token_address': '0xbab6f30c81209433a3ced28ca8e19256440547d9',
#   'name': 'Yu Gi Oh',
#   'symbol': 'YGO',
#   'Numbers': 50.0,
#   'price': 0},
#  {'token_address': '0x076641af1b8f06b7f8c92587156143c109002cbe',
#   'name': 'SoPay',
#   'symbol': 'SOP',
#   'Numbers': 16.0,
#   'price': 0},
#  {'token_address': '0x2f85e502a988af76f7ee6d83b7db8d6c0a823bf9',
#   'name': 'LatiumX',
#   'symbol': 'LATX',
#   'Numbers': 10.0,
#   'price': 0},
#  {'token_address': '0xbddab785b306bcd9fb056da189615cc8ece1d823',
#   'name': 'Ebakus',
#   'symbol': 'EBK',
#   'Numbers': 8.746002661,
#   'price': 0},
#  {'token_address': '0xf3e014fe81267870624132ef3a646b8e83853a96',
#   'name': 'VIN',
#   'symbol': 'VIN',
#   'Numbers': 7.77,
#   'price': 0},
#  {'token_address': '0x2a46f2ffd99e19a89476e2f62270e0a35bbf0756',
#   'name': None,
#   'symbol': None,
#   'Numbers': 7.0,
#   'price': 0},
#  {'token_address': '0x1d16bf5cf1bbffa15983af4b034a795331fe2580',
#   'name': 'House of Medici',
#   'symbol': 'HOM',
#   'Numbers': 6.7,
#   'price': 0},
#  {'token_address': '0xaf47ebbd460f21c2b3262726572ca8812d7143b0',
#   'name': 'Promodl',
#   'symbol': 'PMOD',
#   'Numbers': 5.0,
#   'price': 0},
#  {'token_address': '0x79986af15539de2db9a5086382daeda917a9cf0c',
#   'name': None,
#   'symbol': None,
#   'Numbers': 1.0,
#   'price': 0},
#  {'token_address': '0x8285ed6158579c7f280eaa7c80a5bacc42114921',
#   'name': ' GAntiMatter.Finance ETH Perpetual Bull Token Floor 1500USDC Cap 6000USDC',
#   'symbol': '+ETH($1500)',
#   'Numbers': 1.0,
#   'price': 0},
#  {'token_address': '0x3e91a4c4ce0d6beb50b8bb140accffad080f66ad',
#   'name': 'CORNDAPP',
#   'symbol': 'CORNDAPP',
#   'Numbers': 1.0,
#   'price': 0},
#  {'token_address': '0xfd79c2aa42ab4bfbd7c03c1e6866491172917b32',
#   'name': 'CryptoBotsBattle',
#   'symbol': 'CBTB',
#   'Numbers': 1.0,
#   'price': 0},
#  {'token_address': '0x5f5d0767fb8ba2c2793bf7957993a63b5e67d92b',
#   'name': 'CryptoBots: Idle Token',
#   'symbol': 'CBIT',
#   'Numbers': 1.0,
#   'price': 0},
#  {'token_address': '0x5a8728c23004ac748d5deb30748cb183917beff3',
#   'name': 'PIGCOIN',
#   'symbol': 'PGC2',
#   'Numbers': 1.0,
#   'price': 0},
#  {'token_address': '0x74cac868f2254f1a6b7ca951f0d86eac4a65c132',
#   'name': 'B Wrapped Ether',
#   'symbol': 'bWETH',
#   'Numbers': 3.9e-17,
#   'price': 0}]

# %%
with open('ERC20_TokenList.json', 'w') as outfile:
    outfile.write(json.dumps(erc20_result_list))

# %%
erc20_pie = pd.DataFrame.from_dict(erc20_result_list)
erc20_pie["Total"] = erc20_pie["Numbers"] * erc20_pie["price"]
erc20_pie = erc20_pie[["name", "Numbers", "Total"]].iloc[:20]
erc20_pie = erc20_pie.set_index("name")

erc20_pie.plot.pie(y="Numbers", figsize=(12,12), legend=False, title="Top 20 Total NFT")
# Out:
# <AxesSubplot:title={'center':'Top 20 Total NFT'}, ylabel='Numbers'>

# %%
# url = f"https://api.ethplorer.io/getAddressInfo/{addr}?apiKey=freekey"

# response = requests.get(url, verify=True)
# print(response.text["result"])

# https://api.etherscan.io/api?module=account&action=tokenbalance&contractaddress=0x9e1c80662d04b2c94dce0a46e5b1f5b48ce97e26&address=0x95ebe7d8089d4c8bcee0bde19c9e867cbeeefd00&tag=latest&apikey=57GBAHGQSE3CMYNZQY81V1N32YJZNCCUNZ
# url = "https://api.etherscan.io/api?module=account&action=balancemulti&address=0xddbd2b932c763ba5b1b7ae3b362eac3e8d40121a,0x63a9975ba31b0b9626b34300f7f627147df1f526,0x198ef1ec325a96cc354c7266a038be8b5c558f67&tag=latest&apikey=57GBAHGQSE3CMYNZQY81V1N32YJZNCCUNZ"
